# %% [markdown]
# # Ferguson - 2014
# **Sophia and Victoria**
#
# In Ferguson Missouri the Summer 2014, an unarmed black teenager was shot 6 times and subsequently died from his wounds. The white officer was not indicted by a grand jury 3 months later.
#
# The initial incident and the following decision incited both a physical firestorm as the streets of Ferguson were filled with flame and protests, and virtually through social media as people from around the world weighed in.
#
# This project explores the phenomenon of social media activism, news sharing, and the relationship between the virtual and physical world through analysis of 13 million tweets over the two weeks following the shooting, and 15 million tweets about the indictment decision in the two weeks following.
#
# Specifically, we are interested in the kinds of visualizations helpful for understanding social justice-related events over twitter. Using spatial, temporal, and aggregate type graphs, we present a variety of graphs to highlight the various traits which could make the study of twitter data compelling.

# %% [markdown]
# # Getting a dataset
# To get the dataset of tweets mentioning Ferguson in the time after the shooting and around the time of the indictment, we found the following [list of tweet ids](https://archive.org/details/ferguson-tweet-ids). Since the Twitter API terms of service do not allow posting actual tweet content on the internet, we have to "hydrate" these tweets from their ids.
#
# We did this using a tool called twarc.py. [Documentation Here.](https://github.com/edsu/twarc). This tool allows us to point twarc.py at a file containing tweet ids. Then twarc hydrates the tweets by querying the twitter api for those ids, 100 at a time. In all it took the two of us about a week and a half to collect all the data.
#
# Unfortunately, as [this blog post](http://inkdroid.org/2014/08/30/a-ferguson-twitter-archive/) mentions, there are some gaps in the dataset containing the tweets after the time of the shooting.

# %% [markdown]
# # Importing everthing!
# Let's get ready to do some cool data things! Admittedly, we are using a specil package called [cartopy](http://scitools.org.uk/cartopy/) for mapping. To install, there is a pre-built binary/package for Anaconda which you can get through the command line: `conda install -c scitools cartopy`.

# %%
% matplotlib inline
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
from datetime import date
from datetime import timedelta

import cartopy.crs as ccrs
from ipywidgets import widgets
import matplotlib.cm as cm
import seaborn as sns

from matplotlib import animation
from IPython.display import HTML
from tempfile import NamedTemporaryFile
# Out:
# /Users/Sophia/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# # Reading in Data
# Here, we're using a function that we've developed to read in the data, a certain number of lines at a time. This function will take a while to read in all the tweets.

# %%
def ReadToDf(linesAtATime,filepath, max=-1):
    '''Read in the .json file of all of the tweets and convert them into a dataframe
    
    This function also has an optional argument max that can be used to speficy if only a certain number of tweets 
    are desired.'''
    start = time.time()
    df = pd.DataFrame()
    i = 0
    data = [] 
    
    #Open and read in the file
    with open(filepath) as cleanedTweets:
        for tweet in cleanedTweets:
            i += 1
            jsonline = json.loads(tweet)
            data.append(jsonline)
            #aggregate once we've read in the appropriate number of liens
            if (i % linesAtATime == 0):
                print "number of tweets parsed: ", i
                print "total time elapsed: ", time.time() - start
                df = pd.DataFrame(data=data).append(df)
                #reset the data
                data = []
        #Allow us to handle the last few tweets, and to truncate the data if we just want to run unit tests
            if (max > 0 and i >= max):
                break
        df = pd.DataFrame(data=data).append(df)
    #return the aggregation
    return df

# %%
shooting_df = ReadToDf(500000, 'data/cleanedShootingTweets.json')
# Out:
# number of tweets parsed:  500000
# total time elapsed:  8.42842698097
# number of tweets parsed:  1000000
# total time elapsed:  18.3847298622
# number of tweets parsed:  1500000
# total time elapsed:  29.5955348015
# number of tweets parsed:  2000000
# total time elapsed:  42.0361249447
# number of tweets parsed:  2500000
# total time elapsed:  54.7786529064
# number of tweets parsed:  3000000
# total time elapsed:  68.3164279461
# number of tweets parsed:  3500000
# total time elapsed:  83.3426258564
# number of tweets parsed:  4000000
# total time elapsed:  97.4800388813
# number of tweets parsed:  4500000
# total time elapsed:  114.210583925
# number of tweets parsed:  5000000
# total time elapsed:  132.300080776
# number of tweets parsed:  5500000
# total time elapsed:  148.048592806
# number of tweets parsed:  6000000
# total time elapsed:  168.449382782
# number of tweets parsed:  6500000
# total time elapsed:  187.605800867
# number of tweets parsed:  7000000
# ...

# %%
shooting_df.head(10)
# Out:
#    coordinates_x  coordinates_y                      created_at  \
# 0            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 1            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 2            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 3            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 4            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 5            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 6            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 7            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 8            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 9            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
#
#        entities_hashtags_text entities_user_mentions_id_str  \
# 0                          []                            []
# 1                  [Ferguson]                   [760827962]
# 2                  [Ferguson]                  [1670129570]
# ...

# %%
indictment_df = ReadToDf(500000, 'data/cleanedIndTweets.json')
# Out:
# number of tweets parsed:  500000
# total time elapsed:  18.6331429482
# number of tweets parsed:  1000000
# total time elapsed:  28.0015799999
# number of tweets parsed:  1500000
# total time elapsed:  38.5282449722
# number of tweets parsed:  2000000
# total time elapsed:  50.155023098
# number of tweets parsed:  2500000
# total time elapsed:  61.9974660873
# number of tweets parsed:  3000000
# total time elapsed:  89.0536670685
# number of tweets parsed:  3500000
# total time elapsed:  105.817389965
# number of tweets parsed:  4000000
# total time elapsed:  120.09651494
# number of tweets parsed:  4500000
# total time elapsed:  134.684483051
# number of tweets parsed:  5000000
# total time elapsed:  150.199685097
# number of tweets parsed:  5500000
# total time elapsed:  220.092925072
# number of tweets parsed:  6000000
# total time elapsed:  252.059778929
# number of tweets parsed:  6500000
# total time elapsed:  270.389688969
# number of tweets parsed:  7000000
# ...

# %%
indictment_df.head(10)
# Out:
#    coordinates_x  coordinates_y                      created_at  \
# 0            NaN            NaN  Sun Dec 07 22:22:14 +0000 2014
# 1            NaN            NaN  Sun Dec 07 22:22:14 +0000 2014
# 2            NaN            NaN  Sun Dec 07 22:22:16 +0000 2014
# 3            NaN            NaN  Sun Dec 07 22:22:16 +0000 2014
# 4            NaN            NaN  Sun Dec 07 22:22:16 +0000 2014
# 5            NaN            NaN  Sun Dec 07 22:22:17 +0000 2014
# 6            NaN            NaN  Sun Dec 07 22:22:18 +0000 2014
# 7            NaN            NaN  Sun Dec 07 22:22:18 +0000 2014
# 8            NaN            NaN  Sun Dec 07 22:22:19 +0000 2014
# 9     -122.46199      38.290648  Sun Dec 07 22:22:21 +0000 2014
#
#                              entities_hashtags_text  \
# 0                                                []
# 1          [EricGarner, BlackLivesMatter, Ferguson]
# 2                                        [Ferguson]
# ...

# %% [markdown]
# ## Cleaning Data
# This is where we're going to clean data that we've read in. The only cleaning that we need to do is that we need to convert the "created_at" column to a datetime object. The rest of the cleaning data is done in the script `development_scripts/clean_json_data.py`.

# %%
def recodeData (dataframe):
    # Creating a parseable dataset    
    dataframe['createdDatetime'] =  pd.to_datetime(
        dataframe['created_at'], 
        format = '%a %b %d %H:%M:%S +0000 %Y')
    
    # Pull out hour and date data since we use these a lot and it takes a long time to get to them
    dataframe['createdDatetime_Date'] = dataframe['createdDatetime'].dt.date
    dataframe['createdDatetime_Hour'] = dataframe['createdDatetime'].dt.hour

# %% [markdown]
# Now, let's recode the dates for the shooting data and the indictment data! These opperations are done in place, so we don't actually have to return anything

# %%
print('recoding shooting dataset')
recodeData(shooting_df)
print('recoding indictment dataset')
recodeData(indictment_df)
print('recoded all datasets')
# Out:
# recoding shooting dataset
# recoding indictment dataset
# recoded all datasets

# %% [markdown]
# ## Getting a Subset of the Data
# Here, we are going to get a subset of the data. We are doing this because there is too much data to analyze in a timely manner. If we were going to tell the story of how the twitter world reacted to Ferguson, we would re-run our analysis on the entire dataset.

# %%
shootingSubset = shooting_df[shooting_df.createdDatetime_Date.isin([date(2014,8,14),date(2014,8,15),date(2014,8,16)])]

# %%
shootingSubset.head(10)
# Out:
#    coordinates_x  coordinates_y                      created_at  \
# 0            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 1            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 2            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 3            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 4            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 5            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 6            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 7            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 8            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
# 9            NaN            NaN  Thu Aug 14 13:13:06 +0000 2014
#
#        entities_hashtags_text entities_user_mentions_id_str  \
# 0                          []                            []
# 1                  [Ferguson]                   [760827962]
# 2                  [Ferguson]                  [1670129570]
# ...

# %%
indictmentSubset = indictment_df[indictment_df.createdDatetime_Date.isin([date(2014,11,23),date(2014,11,24),date(2014,11,25)])]

# %%
indictmentSubset.head(10)
# Out:
#    coordinates_x  coordinates_y                      created_at  \
# 0            NaN            NaN  Tue Nov 25 22:13:29 +0000 2014
# 1            NaN            NaN  Tue Nov 25 22:13:29 +0000 2014
# 2            NaN            NaN  Tue Nov 25 22:13:29 +0000 2014
# 3            NaN            NaN  Tue Nov 25 22:13:29 +0000 2014
# 4            NaN            NaN  Tue Nov 25 22:13:29 +0000 2014
# 5            NaN            NaN  Tue Nov 25 22:13:29 +0000 2014
# 6            NaN            NaN  Tue Nov 25 22:13:29 +0000 2014
# 7            NaN            NaN  Tue Nov 25 22:13:29 +0000 2014
# 8            NaN            NaN  Tue Nov 25 22:13:29 +0000 2014
# 9            NaN            NaN  Tue Nov 25 22:13:29 +0000 2014
#
#      entities_hashtags_text entities_user_mentions_id_str  \
# 0  [Atlanta, Ferguson, cnn]                    [16252233]
# 1        [edshow, Ferguson]                    [26379293]
# 2                        []          [34643610, 52419540]
# ...

# %% [markdown]
# # Understanding The Dataset
# In this section, we mostly want to explore broadly the data we have -- both the shooting and indictment-related tweets. We will do this for large scale temporal and spatial visualizations first, followed by more specifically aggregated comparisons amongst different axes of data.

# %% [markdown]
# ## Visualizing the Number of Tweets Over Time
# One of the first things we sought to visualize was the number of tweets over time, expecially as people reacted to important events related to the shooting and indictment. We were interested in seeing whether there were dectectable spikes in the number of tweets mentioning Ferguson as people reacted to these events.
#
# In the dataset related to the shooting, we have approximately 11 million tweets worth of data. Over the course of the first week, statements from police, from the family of Michael Brown, statements from the police officer Darren Wilson, and unrest from the streets were recorded and shared wildly across the web. To get a general understanding of the data, we are going to plot the number of tweets over time and annotate this plot with important events that happened over the course of the two weeks.

# %% [markdown]
# First, we will group the tweets by minute, and then count the number of tweets that happened each minute.

# %%
def plotWithEvents(df,eventlist):
    '''Given a dataframe of tweets, this function will plot those tweets, grouped by minute, and annotate the graph 
    with any events that we would like.'''
    groupedTime = (df.set_index('createdDatetime')
                      .groupby([pd.TimeGrouper('Min')])
                      .count()
                      .reset_index())
    fig, ax = plt.subplots(figsize=(10,10))

    groupedTime.plot(kind='line', x='createdDatetime', y='created_at', ax=ax)
    plt.title('Number of Tweets by Users')

    ax.set_ylabel('Count of tweets')
    ax.set_xlabel('Date/Time')
    
    for i,event in enumerate(eventlist):
        plt.axvline(x=eventlist.get(event).get('date'),ymin=0, ymax=4000, linewidth=4,color='g',label=event)
        plt.text(eventlist.get(event).get('date'),2500 - (eventlist.get(event).get('offset'))*500,event)
    plt.show()

# %% [markdown]
# To put the data in context, we map for a variety of calendar dates and times, as called out by [this](http://www.nytimes.com/interactive/2014/08/13/us/ferguson-missouri-town-under-siege-after-police-shooting.html?_r=0) article.

# %%
#calendar dates learned from a variety of news sources, especially http://www.nytimes.com/interactive/2014/08/13/us/ferguson-missouri-town-under-siege-after-police-shooting.html?_r=0
calendar_dates = {'AntonioFrench': {'date': datetime(2014,8,14,7,0,0), 'offset': 0},
                 'Obama2': {'date': datetime(2014,8,14,11,40,0), 'offset': 1},
                 'SilentVigils': {'date': datetime(2014,8,14,18,0,0), 'offset': 0},
                 'DarrenWilsonNamed': {'date': datetime(2014,8,15,8,45,0), 'offset': 0},
                 'CharacterAssassination': {'date': datetime(2014,8,15,12,30,0), 'offset': 1},
                 'StateOfEmergency': {'date': datetime(2014,8,16,15,0,0), 'offset': 0}}

plotWithEvents(shootingSubset, calendar_dates)

# %% [markdown]
# Now, let's do the same thing for the data regarding the tweets after the indictment!

# %%
calendar_dates = {'IndictmentDecision': {'date': datetime(2014,11,24,20,15,0), 'offset': 0}}
plotWithEvents(indictmentSubset, calendar_dates)

# %% [markdown]
# **Our Thougts on this type of Visualization:**
#
# On the bright side, this type of visualization makes it immediately obvious if there are any gaps in the data, which, unfortunately there are. Additionally, we can see how the number of tweets mentioning Ferguson reacts after important events unfold. One thing that we find expecially interesting is how some events seem to cause a spike in the number of tweets, while some events cause a decrease in the number of tweets.
#
# However, while this visualization tells us about how many people are interacting in the twitter discussion about Ferguson, it does not tell us *who* is interacting or how they interact.

# %% [markdown]
# ## Visualizing the Location of Tweets
# To start to understand who is interacting in the twitter discussion about Ferguson, we decided to start visualizing some of the location-based data that we had. Although many of the tweets are not geo-coded we, wanted to use the tweets that were to get a sense of who was engaging in this dataset, by understanding where people were engaging from.
#
# To do this, we first created a heatmap of the number of tweets origininating across the world.

# %% [markdown]
# Before we get there, though, we have to filter out only the tweets that have location data.

# %%
latLonPopulatedShooting = shootingSubset.dropna(subset=['coordinates_x','coordinates_y'])
latLonPopulatedIndictment = indictmentSubset.dropna(subset=['coordinates_x','coordinates_y'])

# %% [markdown]
# Now, we are going to define a function that plots a heatmap of the number of tweets origininating across the world, or at least a heatmap simulant called hexbin. Further, we should note that this will be a log scale graph, which will allow more clearly for ALL tweets to be visualized, but the density of certain locations to be still visible.

# %%
def createTweetHeatmap(tweetDf):
    #create a simple cartopy map
    plt.figure(figsize=(15,5))
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.coastlines()

    #straight-up coordinate data which we just finished recoding
    plt.hexbin(tweetDf.coordinates_x,tweetDf.coordinates_y,cmap=cm.Reds, bins='log') #add bins='log' to see a log based chart
    cb = plt.colorbar()
    cb.set_label('log10(counts)')
    plt.show()

# %% [markdown]
# And now, let's create some plots!

# %%
createTweetHeatmap(latLonPopulatedShooting)
# Out:
# /Users/Sophia/anaconda/lib/python2.7/site-packages/matplotlib/artist.py:221: MatplotlibDeprecationWarning: This has been deprecated in mpl 1.5, please use the
# axes property.  A removal date has not been set.
#   warnings.warn(_get_axes_msg, mplDeprecation, stacklevel=1)

# %%
createTweetHeatmap(latLonPopulatedIndictment)

# %% [markdown]
# **Our thoughts on this type of visualization:**
#
# First of all, the reason that we used a log-based color scale in these plots is because it makes it easier to see where people are interacting -- otherwise it appears that all of the tweets are coming from Ferguson. We think that this visualization helps us better understand who is interacting in the twitter dataset, as we can begin to see that the Eastern half of the U.S. as well as the West Coast of the U.S tend to be the ones that interact most. There is, however, additionally, a dark point in the middle of the coutry that represents Ferguson. Beyond that, it looks like people all over the world, especially Europe, are talking about Ferguson in our dataset.
#
# After looking at this visualization, one of our thoughts is that it would be interesting to see how many people interact at a given time -- a combination of the first two visualizations. We pursue some variety of this in the following section.

# %% [markdown]
# ### Plotting tweets based on location and time
# As we saw in the last visualization, it would be interesting to create an animation of the number of number of people tweeting from various locations across the world.

# %% [markdown]
# First lets declare some functions that every animation needs, courtesy of and adapted from [this blog](http://jakevdp.github.io/blog/2013/05/12/embedding-matplotlib-animations/).

# %%
#Note, the animation code courtesy of and adapted from http://jakevdp.github.io/blog/2013/05/12/embedding-matplotlib-animations/
VIDEO_TAG = """<video controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.mp4') as f:
            anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264', '-pix_fmt', 'yuv420p'])
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

def display_animation(anim):
    plt.close(anim._fig)
    return HTML(anim_to_html(anim))

# %% [markdown]
# Unfortunately, it's not as easy as we'd like to create functions that create animations for us (the output gets lost), so there will be some copy-and-paste-coding here!

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure(figsize=(10,10))
ax = plt.axes(xlim=(-180, 180), ylim=(-75, 75))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
scat, = plt.plot([], [],'o', alpha=0.2)

# animation function.  This is called sequentially by the animator
def animateShooting(i):
    startDate = date(2014,8,14)
    queryDate = startDate + timedelta(days = round(i/24)) 
    hour = i % 24
    subset = []
    subset = latLonPopulatedShooting[
        (latLonPopulatedShooting['createdDatetime_Date'] == queryDate) & 
        (latLonPopulatedShooting['createdDatetime_Hour'] == hour)]

    scat.set_data(subset.coordinates_x,subset.coordinates_y)
    
    return scat,

# animation.Animation._repr_html_ = anim_to_html #this yields a depreciation warning, heads up
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animateShooting, frames=72, interval=5000, blit=True)

# call our new function to display the animation
display_animation(anim)
# Out:
# <video controls>
#  <source src="...

# %% [markdown]
# And now, the same for the indictment data!

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure(figsize=(10,10))
ax = plt.axes(xlim=(-180, 180), ylim=(-75, 75))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
scat, = plt.plot([], [],'o', alpha=0.2)

# animation function.  This is called sequentially by the animator
def animateInd(i):
    startDate = date(2014,11,23)
    queryDate = startDate + timedelta(days = round(i/24)) 
    hour = i % 24
    subset = []
    subset = latLonPopulatedIndictment[
        (latLonPopulatedIndictment['createdDatetime_Date'] == queryDate) & 
        (latLonPopulatedIndictment['createdDatetime_Hour'] == hour)]

    scat.set_data(subset.coordinates_x,subset.coordinates_y)
    
    return scat,

# animation.Animation._repr_html_ = anim_to_html #this yields a depreciation warning, heads up
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animateInd, frames=72, interval=5000, blit=True)

# call our new function to display the animation
display_animation(anim)
# Out:
# <video controls>
#  <source src="...

# %% [markdown]
# **Our Thoughts on this type of visualization**
#
# We really like this visualization -- it's super cool to see how the world talks about Ferguson, and see when various parts of the world are engaged in the coversation. One insight these plots appear to give us, is that while the rest of the world has some periods in which they talk about Ferguson less, the twitter users in Ferguson are *always* talking about Ferguson. Improvements to such a visualization may stem from incorporating labels for events, over time, allowing a viewer to immediately understand a particular ebb or rise in tweets.
#
# Although now we know where people are engaging, and when they are engaging, this plot still does not tell us *how* users engage in the conversation.

# %% [markdown]
# # Hashtags
# To get at the question of how users are engaging with the dataset, we decided to look at one of twitters unique features: the hashtag. This is a quippy oneword statement often indicated by a pound sign in a post by a user - which twitter has handily aggregated for us already.
#
# To do this exploration, we first have to do a little bit of data re-ordering. Now that we've seen what sorts of visualizations are helpful for understanding the dataset on a very high level, let's explore different methods of visualizing hashtags in the dataset. To do this, let's create a dataframe that has one row per hasthag,tweet combination. So, a tweet using two hashtags would translate into a dataframe with two rows.
#
# In this case, these visualizations take a long time to make and the data takes a long time to reprocess, so we will transition to using only the shooting data here. We are doing this because it seems we learn similar things about how helpful a given visualization is whether or not we are using the shooting or indictment dataset.

# %% [markdown]
# We will create this dataframe by looping over the rows in the dataframe, and looping over the hashtags in each tweet. For each tweet, we will create a json object that represents the row that should be added to our new dataframe.
#
# **Warning:** This is super slow, so don't run this unless you have to

# %%
def convertToHashtagDf (df):
    '''convert a tweet dataframe to a dataframe of hashtags'''
    numprocessed = 0
    hashtagRows = []
    hashtagMap = {'MICHAELBROWN': 'MIKEBROWN'}
    for i,tweet in df.iterrows():
        numprocessed += 1
        if (numprocessed%500000 == 0):
                print('processed {} tweets'.format(numprocessed))
        for hashtag in tweet['entities_hashtags_text']:
            mappedhashtag = hashtag.upper()
            if (mappedhashtag in hashtagMap):
                mappedhashtag = hashtagMap[mappedhashtag]

            hashtagRows.append({
                    'createdDatetime': tweet['createdDatetime'],
                    'hashtag': mappedhashtag,
                    'tweetId': tweet['id_str'],
                    'x': tweet['coordinates_x'],
                    'y': tweet['coordinates_y'],
                    'date': tweet['createdDatetime_Date'],
                    'hour': tweet['createdDatetime_Hour']})
    print "creating dataframe"
    hashtagsDf = pd.DataFrame(hashtagRows)
    return hashtagsDf

# %%
shootingHashtagsDf = convertToHashtagDf(shootingSubset)
# Out:
# processed 500000 tweets
# processed 1000000 tweets
# processed 1500000 tweets
# processed 2000000 tweets
# processed 2500000 tweets
# processed 3000000 tweets
# processed 3500000 tweets
# creating dataframe

# %%
shootingHashtagsDf.head(10)
# Out:
#       createdDatetime        date         hashtag  hour             tweetId  \
# 0 2014-08-14 13:13:06  2014-08-14        FERGUSON    13  499906559552802816
# 1 2014-08-14 13:13:06  2014-08-14        FERGUSON    13  499906559585951746
# 2 2014-08-14 13:13:06  2014-08-14        FERGUSON    13  499906559653449729
# 3 2014-08-14 13:13:06  2014-08-14        FERGUSON    13  499906560190324736
# 4 2014-08-14 13:13:06  2014-08-14        FERGUSON    13  499906560328749057
# 5 2014-08-14 13:13:06  2014-08-14  SISTERPATRIOTS    13  499906560328749057
# 6 2014-08-14 13:13:06  2014-08-14        FERGUSON    13  499906561222139904
# 7 2014-08-14 13:13:06  2014-08-14        FERGUSON    13  499906561251504129
# 8 2014-08-14 13:13:06  2014-08-14        FERGUSON    13  499906561264062464
# 9 2014-08-14 13:13:06  2014-08-14            CUBA    13  499906561645367297
#
#     x   y
# 0 NaN NaN
# 1 NaN NaN
# 2 NaN NaN
# 3 NaN NaN
# 4 NaN NaN
# 5 NaN NaN
# 6 NaN NaN
# 7 NaN NaN
# 8 NaN NaN
# 9 NaN NaN

# %% [markdown]
# Now that we have a dataframe, let's look at the tweets that use hashtags the top 10 hashtags (to get a feel for what people are tweeting)

# %%
numTopHashtags = 10
popularHashtagsList = (shootingHashtagsDf
                   .groupby('hashtag')
                   .count()
                   .reset_index()
                   .sort_values(by='createdDatetime', ascending=False)['hashtag']
                   .tolist())[0:numTopHashtags]

print(popularHashtagsList)
# Out:
# [u'FERGUSON', u'MIKEBROWN', u'GAZA', u'MEDIABLACKOUT', u'JUSTICEFORMIKEBROWN', u'NMOS14', u'DONTSHOOT', u'PALESTINE', u'STL', u'TCOT']

# %% [markdown]
# For framing, these hashtags had/have the following connotations on twitter:
#
# *Ferguson* - a flag for simply talking about the shooting and current events
#
# *MikeBrown* - used often to memorialize the teen
#
# *Gaza* - used to reference other unrest in the world
#
# *MediaBlackout* - initially in reference to reporter arrests, then carried on to imply that reporting in Ferguson failed to tell the whole story or was limited in detail
#
# *JusticeForMikeBrown* - this not only memorialized the teen, but took a stance of decidely PRO-Mike Brown
#
# *NMOS14* - a call for a national moment of silence, peaked during a night of silent vigils both physically, and as the data will show, virtually
#
# *DontShoot* - an allied with Mike Brown or BlackLivesMatter hashtag
#
# *Palestine* - similar to Gaza in purpose
#
# *STL* - used as a flag for the greater metropolitan area, St. Louis
#
# *TCOT* - used as a unifier for Top Conservatives on Twitter
#
# Now that we have the most popular hashtags, let's filter the hashtags dataframe for just those hashtags.

# %%
popularShootingHashtagsDf = shootingHashtagsDf[shootingHashtagsDf.hashtag.isin(popularHashtagsList)]
popularShootingHashtagsDf.head(10)
# Out:
#        createdDatetime        date   hashtag  hour             tweetId   x   y
# 0  2014-08-14 13:13:06  2014-08-14  FERGUSON    13  499906559552802816 NaN NaN
# 1  2014-08-14 13:13:06  2014-08-14  FERGUSON    13  499906559585951746 NaN NaN
# 2  2014-08-14 13:13:06  2014-08-14  FERGUSON    13  499906559653449729 NaN NaN
# 3  2014-08-14 13:13:06  2014-08-14  FERGUSON    13  499906560190324736 NaN NaN
# 4  2014-08-14 13:13:06  2014-08-14  FERGUSON    13  499906560328749057 NaN NaN
# 6  2014-08-14 13:13:06  2014-08-14  FERGUSON    13  499906561222139904 NaN NaN
# 7  2014-08-14 13:13:06  2014-08-14  FERGUSON    13  499906561251504129 NaN NaN
# 8  2014-08-14 13:13:06  2014-08-14  FERGUSON    13  499906561264062464 NaN NaN
# 10 2014-08-14 13:13:06  2014-08-14  FERGUSON    13  499906561704460288 NaN NaN
# 11 2014-08-14 13:13:07  2014-08-14  FERGUSON    13  499906562589478912 NaN NaN

# %% [markdown]
# Now, let's count the number of times each hashtag was used in a given minute. To do this, we will group the dataframe by datetime.minute and hashtag and then aggregate by count.

# %%
hashtagTimeCounts = (popularShootingHashtagsDf
                     .set_index('createdDatetime')
                     .groupby([pd.TimeGrouper(freq=(15,'Min')), 'hashtag'])
                     .count()
                     .reset_index())
hashtagTimeCounts.head(10)
# Out:
#       createdDatetime              hashtag   date   hour  tweetId    x    y
# 0 2014-08-14 00:00:00            DONTSHOOT    289    289      289    0    0
# 1 2014-08-14 00:00:00             FERGUSON  25745  25745    25745  173  173
# 2 2014-08-14 00:00:00                 GAZA    130    130      130    0    0
# 3 2014-08-14 00:00:00  JUSTICEFORMIKEBROWN    286    286      286    0    0
# 4 2014-08-14 00:00:00            MIKEBROWN   3236   3236     3236   16   16
# 5 2014-08-14 00:00:00               NMOS14     18     18       18    0    0
# 6 2014-08-14 00:00:00            PALESTINE     28     28       28    0    0
# 7 2014-08-14 00:00:00                  STL    993    993      993    0    0
# 8 2014-08-14 00:00:00                 TCOT    106    106      106    0    0
# 9 2014-08-14 00:15:00            DONTSHOOT    102    102      102    2    2

# %% [markdown]
# Now that we've gotten the counts for a particular hashtag every 15 minutes, let's plot this over time as a line graph.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

for hashtag in popularHashtagsList:
    filteredHashtagTimeCounts = hashtagTimeCounts[hashtagTimeCounts.hashtag == hashtag]
    filteredHashtagTimeCounts.plot(kind = 'line', x = 'createdDatetime', y = 'tweetId', label = hashtag, ax = ax)
    
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Time')
plt.ylabel('Number of Tweets over Time')
plt.title('Hashtag useage over Time')

# %% [markdown]
# Since the number of tweets using the "ferguson" hashtag is so high, let's also make this plot and remove that line from the dataset.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

for hashtag in popularHashtagsList:
    if (hashtag == 'FERGUSON'):
        continue
    filteredHashtagTimeCounts = hashtagTimeCounts[hashtagTimeCounts.hashtag == hashtag]
    filteredHashtagTimeCounts.plot(kind = 'line', x = 'createdDatetime', y = 'tweetId', label = hashtag, ax = ax)
    
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Time')
plt.ylabel('Number of Tweets over Time')
plt.title('Hashtag useage over Time')

# %% [markdown]
# **Our thoughts on this visualization**
# From this visualization, we can very breifly see trends in hashtags - as they pick up steam, as they persist, or as they die. What's useful about this, is that hashtags serve as both a method of labeling one's own post, or calling out other groups (that perhaps don't share the views in the post). Ferguson and MikeBrown persist because they are general tags which immediately capture, on either side, what is going on. MediaBlackout is more short lived though wildly popular, and was triggered after some arrests of reporters during the unrest in Ferguson.
#
# Since hashtags can be 'polarizing' in the sense that many label what could be perceived as 'sides' of an argument, it would further be interesting to understand who is actually tweeting certain hashtags across the US, thus exploring - are there communities that only tweet certain hashtags? Are they geo-located by stance?

# %% [markdown]
# ## Hashtags by Location

# %% [markdown]
# Thus, to explore geo-located information, we create a new dataframe primarily of populated coordinate information.

# %%
latLonPopulatedHashtags = popularShootingHashtagsDf.dropna(subset=['x','y'])

# %%
latLonPopulatedHashtags.head(10)
# Out:
#          createdDatetime        date   hashtag  hour             tweetId  \
# 35   2014-08-14 13:13:07  2014-08-14  FERGUSON    13  499906566502776832
# 370  2014-08-14 13:13:23  2014-08-14  FERGUSON    13  499906630168088576
# 638  2014-08-14 13:13:33  2014-08-14  FERGUSON    13  499906675026198528
# 816  2014-08-14 13:13:41  2014-08-14  FERGUSON    13  499906705330036736
# 822  2014-08-14 13:13:41  2014-08-14  FERGUSON    13  499906707519471617
# 919  2014-08-14 13:13:45  2014-08-14  FERGUSON    13  499906723331981312
# 1233 2014-08-14 13:13:58  2014-08-14  FERGUSON    13  499906779070087168
# 1307 2014-08-14 13:14:01  2014-08-14  FERGUSON    13  499906790557904898
# 1500 2014-08-14 13:14:09  2014-08-14  FERGUSON    13  499906825593319424
# 1608 2014-08-14 13:14:14  2014-08-14  FERGUSON    13  499906846472540160
#
#               x          y
# 35   -82.729054  28.031176
# 370   10.711095  59.927393
# 638  -77.034159  38.926960
# 816  -77.036776  38.903024
# ...

# %%
def createHashtagHeatmap(hashtag):
    plt.figure(figsize=(10,7))
    subset = latLonPopulatedHashtags[(latLonPopulatedHashtags['hashtag'] == hashtag)]
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.coastlines()
    plt.hexbin(subset.x,subset.y,cmap=cm.Reds,bins='log')
    plt.title(hashtag)
    plt.axis([-180, 0, -75, 75])
    plt.colorbar()

# %%
for hashtag in popularHashtagsList:
    createHashtagHeatmap(hashtag)

# %% [markdown]
# **Our Thoughts on this Visualization**
#
# It becomes immediately obvious that certain locations tend to favor certain hashtags - in example, STL appears only to be used within Ferguson and Missouri, whereas Ferguson, as a more general hashtag, it broadly used. Further, the NMOS14 and MediaBlackout flags have clear aggregations within the US, potentially implying geo-located communities spreading information.
#
# To further our understanding, aggregating hashtags explicitly in support of Mike Brown or the officer Darren Wilson, could also yield more information about the relationship between hashtag users and their perceptions - beyond that of where they may be located.

# %% [markdown]
# ## Hashtags by Alignment
# We start by creating alignment dataframes of different hashtags, then plot the total yield of tweets in these alignments in order to determine whether conclusions can be drawn about the distinctive populations.

# %%
mikeBrown = ['MIKEBROWN', 'HANDSUPDONTSHOOT','JUSTICEFORMIKEBROWN',
             'DONTSHOOT','POLICESTATE','RIPMIKEBROWN',
             'IFTHEYGUNNEDMEDOWN']
darrenWilson = ['TCOT', 'DARRENWILSON', 'UNITEBLUE','TEAPARTY',
                'SUPPORTDARENWILSON', 'GOP']

# %%
mikeBrownDf = (shootingHashtagsDf[shootingHashtagsDf.hashtag.isin(mikeBrown)]
               .set_index('createdDatetime')
               .groupby(pd.TimeGrouper('Min'))
               .count()
               .reset_index())
darrenWilsonDf = (shootingHashtagsDf[shootingHashtagsDf.hashtag.isin(darrenWilson)]
                  .set_index('createdDatetime')
                  .groupby(pd.TimeGrouper('Min'))
                  .count()
                  .reset_index())

# %%
mikeBrownDf.head(10)
# Out:
#       createdDatetime  date  hashtag  hour  tweetId  x  y
# 0 2014-08-14 00:00:00   384      384   384      384  2  2
# 1 2014-08-14 00:01:00   284      284   284      284  4  4
# 2 2014-08-14 00:02:00   220      220   220      220  0  0
# 3 2014-08-14 00:03:00   236      236   236      236  2  2
# 4 2014-08-14 00:04:00   290      290   290      290  0  0
# 5 2014-08-14 00:05:00   348      348   348      348  0  0
# 6 2014-08-14 00:06:00   270      270   270      270  2  2
# 7 2014-08-14 00:07:00   260      260   260      260  2  2
# 8 2014-08-14 00:08:00   274      274   274      274  0  0
# 9 2014-08-14 00:09:00   260      260   260      260  2  2

# %%
darrenWilsonDf.head(10)
# Out:
#       createdDatetime  date  hashtag  hour  tweetId  x  y
# 0 2014-08-14 00:00:00     2        2     2        2  0  0
# 1 2014-08-14 00:01:00     6        6     6        6  0  0
# 2 2014-08-14 00:02:00    10       10    10       10  0  0
# 3 2014-08-14 00:03:00     6        6     6        6  0  0
# 4 2014-08-14 00:04:00     6        6     6        6  0  0
# 5 2014-08-14 00:05:00     6        6     6        6  0  0
# 6 2014-08-14 00:06:00    10       10    10       10  0  0
# 7 2014-08-14 00:07:00    20       20    20       20  0  0
# 8 2014-08-14 00:08:00     6        6     6        6  0  0
# 9 2014-08-14 00:09:00    10       10    10       10  0  0

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

mikeBrownDf.plot(kind='line', x='createdDatetime', y='hashtag', label='Mike Brown Supporters', ax=ax)
darrenWilsonDf.plot(kind='line', x='createdDatetime', y='hashtag', ax = ax, secondary_y=True, label='Darren Wilson Supporters')
plt.title('Number of tweets by Users')

ax.set_ylabel('Count of twets (Mike Brown Supporters)', color='b')
ax.right_ax.set_ylabel('Count of tweets (Darren Wilson Supporters)', color='g')

plt.xlabel('Time')
plt.ylabel('Number of Tweets over Time')
plt.title('Hashtag useage over Time')

# %% [markdown]
# **Our Thoughts on this Visualization**

# %% [markdown]
# There are certainly similar ebbs and peaks in the data, but what is immediately striking is the gain of Darren Wilson aligned tweets with time, as compared to the ebb of Mike Brown aligned tweets. Several relationships with more time could be explored here through detailed network analysis including: did people change their minds as more information was aligned? Did Mike Brown aligned tweeters begin to aggresively parody Darren Wilson aligned tweeters?
#
# A visualization like this of the aggregated, sorted data provides a powerful way of framing the different sides of an 'argument' being played out over social media on a grand scale

# %% [markdown]
# # Conclusions

# %% [markdown]
# The union of spatial and temporal data visualization, coupled with contextual information, we find a compelling way of presenting large amounts of data. Further, aggregation of data metrics based upon research yields opportunity to tell compelling stories and reduce the complexity of the visualization. Opportunities that we were not able to implement - namely selecting other axes to which to aggregate data - may be worthwhile for a person interested in pursuing this particular project in the future. There may also be filtering techniques for the data that could also yield more clean or parseable visualizations.
#
# On the whole, it is clear that making compelling visualizations is a matter of creativity. The opportunity to build interactive graphs is truly an area in which we see strong potential for complex data being shown in a way that a human can interact with fully.
#
# When working with large datasets, it is also critical to understand how long it will take to collect and plot. We went through many iterations of our functions simply so that the time to run each was within a reasonable period of time (on the order of tens of minutes). Using ipython notebooks proved useful for this aspect, as once the data was read in, there was no need to do it again each time something was to be built.
#
# As for understanding social media and it's role in activism, there are clearly some relationships between present activism (physically acting) and virtual activism (voicing support remotely) - namely in observed patterns in Ferguson and Los Angeles, a site of protest during the events. What we were unable to capture here was whether one incited or caused the other, or if the relationship between the media and the actions was primarily active reporting/information spread (reactionary to events). Further work on this project could ask this question and dive more deeply into classifying tweets as action based or support based, triggering or reporting, etc. As a first pass, we are pleased with what these visualizations, and the others we developed along the way through our hypotheses, tell us about the data and have found them compelling with potential to improve.
