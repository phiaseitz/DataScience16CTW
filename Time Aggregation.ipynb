# %%
import json
import time
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
from collections import namedtuple
from ipywidgets import widgets  
from IPython.display import display
% matplotlib inline

# %%
filename = './data/cleanedShootingTweets.json'

# %%
#This works if we don't care about time stuff. 
def ReadAndAggregate(linesAtATime,filepath):
    start = time.time()
    i = 0
    data = []
    hashtagsDict = {}
    
    with open(filename) as cleanedTweets:
        for tweet in cleanedTweets:
            i += 1
            jsonline = json.loads(tweet)
            data.append(jsonline)
            #aggregate
            if (i % linesAtATime == 0):
                print i
                df = pd.DataFrame(data=data)
                allHashtags = df.entities_hashtags_text.tolist()

                for tweet in allHashtags:
                    for hashtag in tweet:
                        hashtagsDict[hashtag.upper()] = hashtagsDict.get(hashtag.upper(), 0) + 1
                
                data = []
    return hashtagsDict

# %%
hashtagsDict = ReadAndAggregate(10000, filename)
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# 1110000
# 1120000
# 1130000
# 1140000
# 1150000
# 1160000
# 1170000
# 1180000
# 1190000
# 1200000
# 1210000
# 1220000
# 1230000
# 1240000
# 1250000
# 1260000
# 1270000
# 1280000
# 1290000
# 1300000
# 1310000
# 1320000
# 1330000
# 1340000
# 1350000
# 1360000
# 1370000
# 1380000
# 1390000
# 1400000
# 1410000
# 1420000
# 1430000
# 1440000
# 1450000
# 1460000
# 1470000
# 1480000
# 1490000
# 1500000
# 1510000
# 1520000
# 1530000
# 1540000
# 1550000
# 1560000
# 1570000
# 1580000
# 1590000
# 1600000
# 1610000
# 1620000
# 1630000
# 1640000
# 1650000
# 1660000
# 1670000
# 1680000
# 1690000
# 1700000
# 1710000
# 1720000
# 1730000
# 1740000
# 1750000
# 1760000
# 1770000
# 1780000
# 1790000
# 1800000
# 1810000
# 1820000
# 1830000
# 1840000
# 1850000
# 1860000
# 1870000
# 1880000
# 1890000
# 1900000
# 1910000
# 1920000
# 1930000
# 1940000
# 1950000
# 1960000
# 1970000
# 1980000
# 1990000
# 2000000
# 2010000
# 2020000
# 2030000
# 2040000
# 2050000
# 2060000
# 2070000
# 2080000
# 2090000
# 2100000
# 2110000
# 2120000
# 2130000
# 2140000
# 2150000
# 2160000
# 2170000
# 2180000
# 2190000
# 2200000
# 2210000
# 2220000
# 2230000
# 2240000
# 2250000
# 2260000
# 2270000
# 2280000
# 2290000
# 2300000
# 2310000
# 2320000
# 2330000
# 2340000
# 2350000
# 2360000
# 2370000
# 2380000
# 2390000
# 2400000
# 2410000
# 2420000
# 2430000
# 2440000
# 2450000
# 2460000
# 2470000
# 2480000
# 2490000
# 2500000
# 2510000
# 2520000
# 2530000
# 2540000
# 2550000
# 2560000
# 2570000
# 2580000
# 2590000
# 2600000
# 2610000
# 2620000
# 2630000
# 2640000
# 2650000
# 2660000
# 2670000
# 2680000
# 2690000
# 2700000
# 2710000
# 2720000
# 2730000
# 2740000
# 2750000
# 2760000
# 2770000
# 2780000
# 2790000
# 2800000
# 2810000
# 2820000
# 2830000
# 2840000
# 2850000
# 2860000
# 2870000
# 2880000
# 2890000
# 2900000
# 2910000
# 2920000
# 2930000
# 2940000
# 2950000
# 2960000
# 2970000
# 2980000
# 2990000
# 3000000
# 3010000
# 3020000
# 3030000
# 3040000
# 3050000
# 3060000
# 3070000
# 3080000
# 3090000
# 3100000
# 3110000
# 3120000
# 3130000
# 3140000
# 3150000
# 3160000
# 3170000
# 3180000
# 3190000
# 3200000
# 3210000
# 3220000
# 3230000
# 3240000
# 3250000
# 3260000
# 3270000
# 3280000
# 3290000
# 3300000
# 3310000
# 3320000
# 3330000
# 3340000
# 3350000
# 3360000
# 3370000
# 3380000
# 3390000
# 3400000
# 3410000
# 3420000
# 3430000
# 3440000
# 3450000
# 3460000
# 3470000
# 3480000
# 3490000
# 3500000
# 3510000
# 3520000
# 3530000
# 3540000
# 3550000
# 3560000
# 3570000
# 3580000
# 3590000
# 3600000
# 3610000
# 3620000
# 3630000
# 3640000
# 3650000
# 3660000
# 3670000
# 3680000
# 3690000
# 3700000
# 3710000
# 3720000
# 3730000
# 3740000
# 3750000
# 3760000
# 3770000
# 3780000
# 3790000
# 3800000
# 3810000
# 3820000
# 3830000
# 3840000
# 3850000
# 3860000
# 3870000
# 3880000
# 3890000
# 3900000
# 3910000
# 3920000
# 3930000
# 3940000
# 3950000

# %%
sortedByCount = sorted(hashtagsDict.items(), key=lambda x: (x[1],x[0]), reverse=True)

splitintoTwoLists = [list(t) for t in zip(*sortedByCount)]
hashtags = splitintoTwoLists[0]
counts = splitintoTwoLists[1]

# %%
plt.bar(range(len(counts[0:20])), counts[0:20], width = 1)
plt.xticks([x+0.5 for x in range(len(counts[0:20]))], hashtags[0:20], rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x105f9b190>,
#   <matplotlib.axis.XTick at 0x116bcaf50>,
#   <matplotlib.axis.XTick at 0x11126eed0>,
#   <matplotlib.axis.XTick at 0x1163e69d0>,
#   <matplotlib.axis.XTick at 0x1151f1290>,
#   <matplotlib.axis.XTick at 0x1151f1950>,
#   <matplotlib.axis.XTick at 0x115597850>,
#   <matplotlib.axis.XTick at 0x115597f10>,
#   <matplotlib.axis.XTick at 0x1155a8550>,
#   <matplotlib.axis.XTick at 0x1155a87d0>,
#   <matplotlib.axis.XTick at 0x114a2bc10>,
#   <matplotlib.axis.XTick at 0x114a2b750>,
#   <matplotlib.axis.XTick at 0x11580bc10>,
#   <matplotlib.axis.XTick at 0x11580bb90>,
#   <matplotlib.axis.XTick at 0x1149350d0>,
#   <matplotlib.axis.XTick at 0x114935b10>,
#   <matplotlib.axis.XTick at 0x115776490>,
#   <matplotlib.axis.XTick at 0x115776510>,
#   <matplotlib.axis.XTick at 0x115776250>,
#   <matplotlib.axis.XTick at 0x114dd8b50>],
#  <a list of 20 Text xticklabel objects>)

# %%
#This works if we don't care about time stuff. 
def ReadAndAggregateIntervals(linesAtATime,filepath):
    start = time.time()
    i = 0
    data = []
    hashtagsDict = {}
    HashtagKey = namedtuple("HashtagKey", ["DoM", "Hour", "Text"])
    
    with open(filename) as cleanedTweets:
        for tweet in cleanedTweets:
            i += 1
            jsonline = json.loads(tweet)
            data.append(jsonline)
            #aggregate
            if (i % linesAtATime == 0):
                print i
                df = pd.DataFrame(data=data)
                df['DoM'] = df['created_at'].apply(lambda x: str(x)[8:10:])
                df['Hour'] = df['created_at'].apply(lambda x: int(str(x)[11:13:]))
#                 df['Minute'] = df['created_at'].apply(lambda x: int(str(x)[14:16:]))
                
                #create a dictionary of month, day of month, hour, hashtag, to count
                allHashtags = df.entities_hashtags_text.tolist()
                
                for index,tweet in df.iterrows():
                    for hashtag in tweet['entities_hashtags_text']:
                        hashtagsDict[HashtagKey(
                                tweet["DoM"], 
                                tweet["Hour"], 
                                hashtag.upper())] = hashtagsDict.get((tweet["DoM"],
                                                             tweet["Hour"],
                                                             hashtag.upper()), 0) + 1
                
                data = []
    return hashtagsDict

# %%
aggDict = ReadAndAggregateIntervals(100000,filename)
# Out:
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# 3300000
# 3400000
# 3500000
# 3600000
# 3700000
# 3800000
# 3900000

# %%
test = pd.read_pickle('./data.pkl')

# %%
aggDict
# Out:
# {HashtagKey(DoM='15', Hour=2, Text=u'data'): 2,
#  HashtagKey(DoM='17', Hour=20, Text=u'sundowntown'): 1,
#  HashtagKey(DoM='21', Hour=0, Text=u'gopFAIL'): 1,
#  HashtagKey(DoM='19', Hour=11, Text=u'NationalRoundup'): 1,
#  HashtagKey(DoM='14', Hour=18, Text=u'TheWholeWorldisWatching'): 1,
#  HashtagKey(DoM='20', Hour=20, Text=u'iHQ'): 1,
#  HashtagKey(DoM='19', Hour=15, Text=u'justiceforformikebrown'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'UniteRight'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'wearethepeople'): 1,
#  HashtagKey(DoM='15', Hour=1, Text=u'TheWrap'): 1,
#  HashtagKey(DoM='21', Hour=3, Text=u'TheFeedSBS2'): 3,
#  HashtagKey(DoM='19', Hour=13, Text=u'Fe'): 2,
#  HashtagKey(DoM='15', Hour=3, Text=u'80s'): 1,
#  HashtagKey(DoM='18', Hour=2, Text=u'FLASHBACK'): 1,
#  HashtagKey(DoM='20', Hour=7, Text=u'whiteallies'): 2,
#  HashtagKey(DoM='19', Hour=14, Text=u'LHHATL'): 3,
#  HashtagKey(DoM='19', Hour=19, Text=u'Idiots'): 6,
#  HashtagKey(DoM='14', Hour=15, Text=u'HU'): 23,
#  HashtagKey(DoM='17', Hour=22, Text=u'EricGarner'): 7,
#  HashtagKey(DoM='20', Hour=1, Text=u'PHX'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'letvoicesbeheard'): 1,
#  HashtagKey(DoM='18', Hour=2, Text=u'moedchat'): 14,
#  HashtagKey(DoM='18', Hour=4, Text=u'pleasestop'): 1,
#  HashtagKey(DoM='19', Hour=15, Text=u'\ub3c5\ub9bd\uc6b4\ub3d9'): 2,
#  HashtagKey(DoM='20', Hour=11, Text=u'FreePress'): 7,
#  HashtagKey(DoM='21', Hour=0, Text=u'justice4michealbrown'): 2,
#  HashtagKey(DoM='20', Hour=14, Text=u'TLOT'): 3,
#  HashtagKey(DoM='19', Hour=14, Text=u'policies'): 1,
#  HashtagKey(DoM='19', Hour=10, Text=u'contropiano'): 2,
#  HashtagKey(DoM='20', Hour=0, Text=u'WillfullyBlind'): 1,
#  HashtagKey(DoM='20', Hour=4, Text=u'ThatAwkwardMoment'): 1,
#  HashtagKey(DoM='19', Hour=6, Text=u'globalawakening'): 1,
#  HashtagKey(DoM='19', Hour=19, Text=u'Gunviolenceagainstchildren'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'smoke'): 1,
#  HashtagKey(DoM='14', Hour=21, Text=u'ReadRothbard'): 1,
#  HashtagKey(DoM='19', Hour=7, Text=u'FergusonIraqi'): 1,
#  HashtagKey(DoM='17', Hour=19, Text=u'purge'): 1,
#  HashtagKey(DoM='20', Hour=7, Text=u'RCfeed'): 1,
#  HashtagKey(DoM='18', Hour=5, Text=u'facts'): 1,
#  HashtagKey(DoM='17', Hour=18, Text=u'Realshit'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'gawker'): 2,
#  HashtagKey(DoM='18', Hour=3, Text=u'gold'): 2,
#  HashtagKey(DoM='20', Hour=10, Text=u'LosMiniDelSonido'): 6,
#  HashtagKey(DoM='19', Hour=11, Text=u'NLG'): 2,
#  HashtagKey(DoM='20', Hour=0, Text=u'UniteBlue'): 141,
#  HashtagKey(DoM='20', Hour=12, Text=u'RequiresLeadership'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'Whats4Sure'): 1,
#  HashtagKey(DoM='19', Hour=19, Text=u'soulbounce'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'DonCornelius'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'SBOT'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'AJStream'): 3,
#  HashtagKey(DoM='19', Hour=21, Text=u'WeareallFerguson'): 1,
#  HashtagKey(DoM='18', Hour=0, Text=u'ImNotKidding'): 2,
#  HashtagKey(DoM='20', Hour=11, Text=u'Moscow'): 7,
#  HashtagKey(DoM='18', Hour=4, Text=u'dumb'): 1,
#  HashtagKey(DoM='20', Hour=8, Text=u'CivilRightsViolation'): 1,
#  HashtagKey(DoM='20', Hour=6, Text=u'monde'): 3,
#  HashtagKey(DoM='19', Hour=6, Text=u'localOVEReverything'): 2,
#  HashtagKey(DoM='20', Hour=2, Text=u'SethStoughton'): 3,
#  HashtagKey(DoM='21', Hour=1, Text=u'WrongAnswer'): 1,
#  HashtagKey(DoM='19', Hour=16, Text=u'UNnews'): 1,
#  HashtagKey(DoM='18', Hour=5, Text=u'racebaiters'): 1,
#  HashtagKey(DoM='20', Hour=3, Text=u'factsonly'): 1,
#  HashtagKey(DoM='14', Hour=18, Text=u'PoliceRiot'): 1,
#  HashtagKey(DoM='15', Hour=8, Text=u'MIFF2014'): 2,
#  HashtagKey(DoM='15', Hour=1, Text=u'FergusonPlaylist'): 1,
#  HashtagKey(DoM='19', Hour=16, Text=u'endgame'): 1,
#  HashtagKey(DoM='20', Hour=7, Text=u'CrownHeights'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'Witnesses'): 1,
#  HashtagKey(DoM='19', Hour=16, Text=u'ACAB'): 6,
#  HashtagKey(DoM='20', Hour=4, Text=u'swaggaband'): 1,
#  HashtagKey(DoM='19', Hour=8, Text=u'newblackpanthers'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'Biggerthanferguson'): 1,
#  HashtagKey(DoM='20', Hour=6, Text=u'Death'): 1,
#  HashtagKey(DoM='17', Hour=21, Text=u'Cardinals'): 6,
#  HashtagKey(DoM='19', Hour=12, Text=u'marketingdirecto'): 1,
#  HashtagKey(DoM='17', Hour=22, Text=u'FaceTheNation'): 1,
#  HashtagKey(DoM='20', Hour=3, Text=u'AmeriKKKa'): 6,
#  HashtagKey(DoM='17', Hour=21, Text=u'FreedomSummerr'): 1,
#  HashtagKey(DoM='15', Hour=0, Text=u'C2GTHR'): 1,
#  HashtagKey(DoM='20', Hour=13, Text=u'EE'): 4,
#  HashtagKey(DoM='19', Hour=16, Text=u'Libertarian'): 1,
#  HashtagKey(DoM='20', Hour=11, Text=u'mo'): 6,
#  HashtagKey(DoM='17', Hour=21, Text=u'racism'): 21,
#  HashtagKey(DoM='17', Hour=22, Text=u'FastandFurious'): 5,
#  HashtagKey(DoM='18', Hour=3, Text=u'GOP'): 16,
#  HashtagKey(DoM='21', Hour=0, Text=u'vote5sos'): 3,
#  HashtagKey(DoM='19', Hour=22, Text=u'BadTimesforJournos'): 1,
#  HashtagKey(DoM='17', Hour=20, Text=u'conversation'): 7,
#  HashtagKey(DoM='20', Hour=14, Text=u'Navy'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'MikeWilson'): 7,
#  HashtagKey(DoM='19', Hour=11, Text=u'Resistencia'): 2,
#  HashtagKey(DoM='19', Hour=16, Text=u'WhiteMaleSupremacy'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'CBSnews'): 4,
#  HashtagKey(DoM='18', Hour=4, Text=u'CartoDB'): 1,
#  HashtagKey(DoM='18', Hour=1, Text=u'holder'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'liberals'): 1,
#  HashtagKey(DoM='19', Hour=18, Text=u'\u0645\u064a\u0632\u0648\u0631\u064a'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'SoundHound'): 1,
#  HashtagKey(DoM='20', Hour=19, Text=u'OfficerGoFuckYourSelf'): 3,
#  HashtagKey(DoM='19', Hour=8, Text=u'eri'): 2,
#  HashtagKey(DoM='19', Hour=5, Text=u'Battleground'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'Time'): 1,
#  HashtagKey(DoM='17', Hour=23, Text=u'AllRaces'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'OdavelyMusic'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'MIkeBrown'): 5,
#  HashtagKey(DoM='20', Hour=12, Text=u'anti'): 1,
#  HashtagKey(DoM='19', Hour=21, Text=u'balle'): 1,
#  HashtagKey(DoM='20', Hour=15, Text=u'NationInDistress'): 5,
#  HashtagKey(DoM='19', Hour=19, Text=u'Militia'): 1,
#  HashtagKey(DoM='17', Hour=21, Text=u'newsnight'): 5,
#  HashtagKey(DoM='14', Hour=16, Text=u'ppl'): 1,
#  HashtagKey(DoM='20', Hour=10, Text=u'gop'): 15,
#  HashtagKey(DoM='20', Hour=14, Text=u'Libya'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'nextlevelshit'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'islam'): 1,
#  HashtagKey(DoM='20', Hour=1, Text=u'tgdn'): 45,
#  HashtagKey(DoM='14', Hour=16, Text=u'JohnLegend'): 27,
#  HashtagKey(DoM='17', Hour=23, Text=u'handsUp'): 1,
#  HashtagKey(DoM='15', Hour=1, Text=u'CivilDebate'): 1,
#  HashtagKey(DoM='19', Hour=5, Text=u'moralmondays'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'humanity'): 2,
#  HashtagKey(DoM='19', Hour=5, Text=u'MissouriGov'): 7,
#  HashtagKey(DoM='18', Hour=4, Text=u'NewOrleans'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'stl'): 233,
#  HashtagKey(DoM='20', Hour=2, Text=u'RiverWalkNOLA'): 1,
#  HashtagKey(DoM='19', Hour=19, Text=u'again'): 1,
#  HashtagKey(DoM='20', Hour=19, Text=u'StandUp'): 2,
#  HashtagKey(DoM='17', Hour=19, Text=u'pjnet'): 35,
#  HashtagKey(DoM='20', Hour=13, Text=u'FuckJustice'): 1,
#  HashtagKey(DoM='20', Hour=0, Text=u'llws'): 1,
#  HashtagKey(DoM='17', Hour=21, Text=u'milwaukee'): 9,
#  HashtagKey(DoM='14', Hour=16, Text=u'BreakingNews'): 27,
#  HashtagKey(DoM='20', Hour=11, Text=u'\uce74\ub77c'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'Guns'): 3,
#  HashtagKey(DoM='17', Hour=22, Text=u'England'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'NativeAmerican'): 2,
#  HashtagKey(DoM='21', Hour=0, Text=u'wordpress'): 1,
#  HashtagKey(DoM='15', Hour=1, Text=u'tbt'): 9,
#  HashtagKey(DoM='17', Hour=23, Text=u'uppers'): 3,
#  HashtagKey(DoM='21', Hour=2, Text=u'TBGWT'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'SenatorGovernor'): 1,
#  HashtagKey(DoM='19', Hour=23, Text=u'AlJazeera'): 13,
#  HashtagKey(DoM='20', Hour=3, Text=u'Donbas'): 1,
#  HashtagKey(DoM='19', Hour=6, Text=u'TeamEM_'): 5,
#  HashtagKey(DoM='20', Hour=23, Text=u'solidaity'): 3,
#  HashtagKey(DoM='19', Hour=9, Text=u'technologynews'): 1,
#  HashtagKey(DoM='17', Hour=20, Text=u'QLShow'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'nyc'): 13,
#  HashtagKey(DoM='18', Hour=4, Text=u'Noticias'): 3,
#  HashtagKey(DoM='18', Hour=2, Text=u'CorreoDelOrinoco'): 2,
#  HashtagKey(DoM='20', Hour=18, Text=u'lasvegas'): 2,
#  HashtagKey(DoM='20', Hour=23, Text=u'Revenge'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'WhiteCooptingOfBlackPain'): 5,
#  HashtagKey(DoM='15', Hour=0, Text=u'BB4SP'): 8,
#  HashtagKey(DoM='20', Hour=18, Text=u'economy'): 2,
#  HashtagKey(DoM='20', Hour=10, Text=u'SaveMissouri'): 1,
#  HashtagKey(DoM='20', Hour=19, Text=u'RealisticExpectations'): 1,
#  HashtagKey(DoM='20', Hour=21, Text=u'marjorieiam'): 2,
#  HashtagKey(DoM='17', Hour=18, Text=u'jo'): 1,
#  HashtagKey(DoM='21', Hour=2, Text=u'thinkpeace'): 1,
#  HashtagKey(DoM='20', Hour=12, Text=u'NewsVideos'): 3,
#  HashtagKey(DoM='15', Hour=10, Text=u'polic\xeda'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'dw_english'): 1,
#  HashtagKey(DoM='20', Hour=4, Text=u'Fergunson'): 2,
#  HashtagKey(DoM='19', Hour=17, Text=u'journosecurity'): 12,
#  HashtagKey(DoM='19', Hour=17, Text=u'wewillbeheard'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'transparency'): 1,
#  HashtagKey(DoM='17', Hour=21, Text=u'Photo'): 2,
#  HashtagKey(DoM='20', Hour=0, Text=u'selectivejustice'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'URGENTE'): 4,
#  HashtagKey(DoM='19', Hour=21, Text=u'UrbNation'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'jaynixon'): 2,
#  HashtagKey(DoM='20', Hour=2, Text=u'Moot'): 1,
#  HashtagKey(DoM='20', Hour=20, Text=u'famous'): 1,
#  HashtagKey(DoM='19', Hour=8, Text=u'monde'): 1,
#  HashtagKey(DoM='20', Hour=5, Text=u'Powerful'): 2,
#  HashtagKey(DoM='20', Hour=16, Text=u'indymulticultural'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'michaelBrown'): 2,
#  HashtagKey(DoM='19', Hour=16, Text=u'euromaidan'): 3,
#  HashtagKey(DoM='14', Hour=17, Text=u'askthedragon'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'exhibitiongame'): 1,
#  HashtagKey(DoM='19', Hour=11, Text=u'Brooklyn'): 1,
#  HashtagKey(DoM='18', Hour=1, Text=u'Cardinals'): 4,
#  HashtagKey(DoM='19', Hour=8, Text=u'inequality'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'county'): 2,
#  HashtagKey(DoM='19', Hour=21, Text=u'hawaii'): 3,
#  HashtagKey(DoM='21', Hour=3, Text=u'theneeds'): 3,
#  HashtagKey(DoM='19', Hour=7, Text=u'discrimination'): 3,
#  HashtagKey(DoM='20', Hour=2, Text=u'JhonsonFresz'): 2,
#  HashtagKey(DoM='20', Hour=3, Text=u'mcfc'): 1,
#  HashtagKey(DoM='18', Hour=5, Text=u'pittsburgh'): 1,
#  HashtagKey(DoM='20', Hour=12, Text=u'YahooFinance'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'locals'): 2,
#  HashtagKey(DoM='20', Hour=22, Text=u'Cleveland'): 3,
#  HashtagKey(DoM='15', Hour=2, Text=u'confused'): 2,
#  HashtagKey(DoM='20', Hour=3, Text=u'VoterFraud'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'BlackLifeMatters'): 2,
#  HashtagKey(DoM='20', Hour=1, Text=u'HeavyHeart'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'NOT'): 1,
#  HashtagKey(DoM='17', Hour=23, Text=u'OmarAbrego'): 13,
#  HashtagKey(DoM='19', Hour=12, Text=u'STLOUIS'): 2,
#  HashtagKey(DoM='14', Hour=21, Text=u'nomore'): 2,
#  HashtagKey(DoM='21', Hour=3, Text=u'stlwx'): 2,
#  HashtagKey(DoM='19', Hour=22, Text=u'americans'): 1,
#  HashtagKey(DoM='20', Hour=15, Text=u'AbEd'): 3,
#  HashtagKey(DoM='19', Hour=15, Text=u'Dreamers'): 1,
#  HashtagKey(DoM='17', Hour=22, Text=u'World'): 3,
#  HashtagKey(DoM='19', Hour=22, Text=u'GeorgeBush'): 1,
#  HashtagKey(DoM='20', Hour=6, Text=u'DNC'): 1,
#  HashtagKey(DoM='19', Hour=21, Text=u'AmateurHour'): 1,
#  HashtagKey(DoM='19', Hour=13, Text=u'M\xe9xico'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'health'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'Diversity'): 1,
#  HashtagKey(DoM='20', Hour=20, Text=u'do'): 1,
#  HashtagKey(DoM='19', Hour=14, Text=u'RonaldJohnson'): 2,
#  HashtagKey(DoM='20', Hour=5, Text=u'HELLO'): 1,
#  HashtagKey(DoM='18', Hour=0, Text=u'mtl'): 2,
#  HashtagKey(DoM='21', Hour=2, Text=u'JustBeingHonest'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'latino'): 4,
#  HashtagKey(DoM='19', Hour=16, Text=u'WhiteTrash'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'gawker'): 1,
#  HashtagKey(DoM='17', Hour=19, Text=u'NoExcuse'): 1,
#  HashtagKey(DoM='19', Hour=14, Text=u'AtlantaStandsWithFerguson'): 3,
#  HashtagKey(DoM='14', Hour=14, Text=u'AR2'): 3,
#  HashtagKey(DoM='19', Hour=11, Text=u'fightfortruth'): 1,
#  HashtagKey(DoM='19', Hour=7, Text=u'FB'): 1,
#  HashtagKey(DoM='17', Hour=19, Text=u'StepUp'): 1,
#  HashtagKey(DoM='21', Hour=2, Text=u'ccot'): 39,
#  HashtagKey(DoM='21', Hour=3, Text=u'coleworld'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'hacker'): 1,
#  HashtagKey(DoM='17', Hour=19, Text=u'la'): 1,
#  HashtagKey(DoM='19', Hour=17, Text=u'CleoWillis'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'MamiiGuerrero'): 11,
#  HashtagKey(DoM='20', Hour=17, Text=u'Suspense'): 4,
#  HashtagKey(DoM='14', Hour=16, Text=u'whataworldwrlivein'): 1,
#  HashtagKey(DoM='17', Hour=17, Text=u'notapolicestate'): 1,
#  HashtagKey(DoM='18', Hour=1, Text=u'iam'): 5,
#  HashtagKey(DoM='15', Hour=8, Text=u'rp'): 1,
#  HashtagKey(DoM='15', Hour=7, Text=u'GetReal'): 1,
#  HashtagKey(DoM='19', Hour=23, Text=u'Ridiculousness'): 1,
#  HashtagKey(DoM='14', Hour=16, Text=u'chicago'): 20,
#  HashtagKey(DoM='14', Hour=22, Text=u'Benghazi'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'class'): 1,
#  HashtagKey(DoM='20', Hour=23, Text=u'FERGUSON'): 148,
#  HashtagKey(DoM='19', Hour=14, Text=u'lepoint'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'Egipto'): 1,
#  HashtagKey(DoM='17', Hour=20, Text=u'ozonepark'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'goodnight'): 1,
#  HashtagKey(DoM='20', Hour=0, Text=u'LateSunday'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'TheLeftovers'): 5,
#  HashtagKey(DoM='20', Hour=18, Text=u'HighwayPatrolCapt'): 1,
#  HashtagKey(DoM='18', Hour=0, Text=u'WestFlorissant'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'ThisIsNotLA'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'BaltimoreForFerguson'): 12,
#  HashtagKey(DoM='19', Hour=20, Text=u'iphone'): 1,
#  HashtagKey(DoM='19', Hour=12, Text=u'productive'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'AboutU'): 1,
#  HashtagKey(DoM='21', Hour=3, Text=u'DarrellWilson'): 8,
#  HashtagKey(DoM='19', Hour=19, Text=u'Madrid'): 2,
#  HashtagKey(DoM='19', Hour=7, Text=u'cancer'): 3,
#  HashtagKey(DoM='19', Hour=15, Text=u'ABD'): 3,
#  HashtagKey(DoM='19', Hour=13, Text=u'MaybeOneDay'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'dreamdefenders'): 6,
#  HashtagKey(DoM='20', Hour=21, Text=u'LAW'): 1,
#  HashtagKey(DoM='15', Hour=9, Text=u'UEFASuperCup'): 1,
#  HashtagKey(DoM='15', Hour=7, Text=u'DONTSHOOT'): 75,
#  HashtagKey(DoM='19', Hour=13, Text=u'don'): 1,
#  HashtagKey(DoM='21', Hour=2, Text=u'pleaseexplain'): 4,
#  HashtagKey(DoM='15', Hour=0, Text=u'ChicagoStandsWithFerguson'): 1,
#  HashtagKey(DoM='20', Hour=15, Text=u'Dinosaurs'): 2,
#  HashtagKey(DoM='20', Hour=23, Text=u'NMOS14'): 5,
#  HashtagKey(DoM='19', Hour=10, Text=u'MUNDO'): 1,
#  HashtagKey(DoM='17', Hour=21, Text=u'Madison'): 1,
#  HashtagKey(DoM='20', Hour=7, Text=u'isitok'): 1,
#  HashtagKey(DoM='14', Hour=17, Text=u'protestors'): 1,
#  HashtagKey(DoM='18', Hour=5, Text=u'NBC'): 6,
#  HashtagKey(DoM='14', Hour=16, Text=u'COGIC'): 1,
#  HashtagKey(DoM='20', Hour=19, Text=u'fastandfurious'): 1,
#  HashtagKey(DoM='20', Hour=4, Text=u'getoffthestreets'): 1,
#  HashtagKey(DoM='15', Hour=7, Text=u'facts'): 1,
#  HashtagKey(DoM='14', Hour=17, Text=u'War'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'FamiilyPretty'): 3,
#  HashtagKey(DoM='19', Hour=5, Text=u'Eyeroll'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'Nachrichten'): 1,
#  HashtagKey(DoM='15', Hour=0, Text=u'Racist'): 3,
#  HashtagKey(DoM='19', Hour=10, Text=u'BeProud'): 1,
#  HashtagKey(DoM='17', Hour=18, Text=u'Lulz'): 1,
#  HashtagKey(DoM='17', Hour=18, Text=u'ItWasTearGas'): 3,
#  HashtagKey(DoM='15', Hour=3, Text=u'MS'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'HaralsonEstates'): 1,
#  HashtagKey(DoM='17', Hour=21, Text=u'REAL'): 11,
#  HashtagKey(DoM='19', Hour=10, Text=u'journalist'): 5,
#  HashtagKey(DoM='14', Hour=23, Text=u'Dayofrage'): 1,
#  HashtagKey(DoM='20', Hour=19, Text=u'Alcatraz'): 1,
#  HashtagKey(DoM='17', Hour=19, Text=u'Failed'): 5,
#  HashtagKey(DoM='17', Hour=18, Text=u'mispronounced'): 1,
#  HashtagKey(DoM='20', Hour=9, Text=u'recall'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'TodayIsGoingToBeAGodDay'): 1,
#  HashtagKey(DoM='19', Hour=11, Text=u'KoranIndonesia'): 1,
#  HashtagKey(DoM='14', Hour=17, Text=u'News19'): 2,
#  HashtagKey(DoM='20', Hour=21, Text=u'dv8PSA'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'TeamYokelChang'): 3,
#  HashtagKey(DoM='14', Hour=16, Text=u'ThingsFergusonMayorBelieves'): 2,
#  HashtagKey(DoM='19', Hour=7, Text=u'Cnn'): 2,
#  HashtagKey(DoM='17', Hour=22, Text=u'MikeBrownrally'): 6,
#  HashtagKey(DoM='20', Hour=13, Text=u'Atlantico'): 1,
#  HashtagKey(DoM='15', Hour=10, Text=u'michaelbrown'): 2,
#  HashtagKey(DoM='19', Hour=13, Text=u'Fallujah'): 1,
#  HashtagKey(DoM='21', Hour=0, Text=u'misouri'): 1,
#  HashtagKey(DoM='14', Hour=17, Text=u'GivingUpRightsForFalseSecurity'): 1,
#  HashtagKey(DoM='19', Hour=17, Text=u'Crazy'): 1,
#  HashtagKey(DoM='19', Hour=16, Text=u'USA'): 92,
#  HashtagKey(DoM='15', Hour=3, Text=u'BorderCrisis'): 1,
#  HashtagKey(DoM='19', Hour=21, Text=u'Wiserswhiskeyquestionoftheday'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'Gunshots'): 1,
#  HashtagKey(DoM='20', Hour=11, Text=u'wasteoftime'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'DanaLoesch'): 1,
#  HashtagKey(DoM='20', Hour=3, Text=u'UStream'): 5,
#  HashtagKey(DoM='20', Hour=20, Text=u'dc'): 1,
#  HashtagKey(DoM='19', Hour=19, Text=u'ISISHere'): 1,
#  HashtagKey(DoM='19', Hour=16, Text=u'stelleastisce'): 1,
#  HashtagKey(DoM='20', Hour=8, Text=u'SweqOverEverything'): 1,
#  HashtagKey(DoM='20', Hour=23, Text=u'Sheeple'): 4,
#  HashtagKey(DoM='21', Hour=2, Text=u'hewitt'): 1,
#  HashtagKey(DoM='21', Hour=0, Text=u'iraq'): 1,
#  HashtagKey(DoM='19', Hour=21, Text=u'Retweet'): 2,
#  HashtagKey(DoM='17', Hour=22, Text=u'Iraque'): 1,
#  HashtagKey(DoM='17', Hour=22, Text=u'Salute'): 5,
#  HashtagKey(DoM='17', Hour=22, Text=u'cuba'): 3,
#  HashtagKey(DoM='19', Hour=8, Text=u'isaac_alvarez01'): 1,
#  HashtagKey(DoM='18', Hour=1, Text=u'Brazil'): 2,
#  HashtagKey(DoM='14', Hour=22, Text=u'OccupyFerguson'): 3,
#  HashtagKey(DoM='19', Hour=13, Text=u'SpecialReport'): 1,
#  HashtagKey(DoM='20', Hour=12, Text=u'therevolution'): 1,
#  HashtagKey(DoM='20', Hour=4, Text=u'toosoon'): 2,
#  HashtagKey(DoM='19', Hour=20, Text=u'blackandbrown'): 1,
#  HashtagKey(DoM='14', Hour=23, Text=u'RCf'): 1,
#  HashtagKey(DoM='14', Hour=15, Text=u'PoliceCruzers'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'nytimes'): 1,
#  HashtagKey(DoM='19', Hour=17, Text=u'DroolNews'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'concluFerguson'): 1,
#  HashtagKey(DoM='19', Hour=17, Text=u'ModiMinistry'): 2,
#  HashtagKey(DoM='15', Hour=9, Text=u'WakeTheSheeple'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'trending'): 2,
#  HashtagKey(DoM='18', Hour=3, Text=u'247newsnaija'): 1,
#  HashtagKey(DoM='14', Hour=20, Text=u'outofhand'): 1,
#  HashtagKey(DoM='20', Hour=15, Text=u'blessings'): 1,
#  HashtagKey(DoM='15', Hour=8, Text=u'Hugs'): 1,
#  HashtagKey(DoM='19', Hour=17, Text=u'BREAKINGNEWS'): 1,
#  HashtagKey(DoM='20', Hour=9, Text=u'ABD'): 3,
#  HashtagKey(DoM='20', Hour=20, Text=u'world'): 7,
#  HashtagKey(DoM='17', Hour=22, Text=u'MarlenePinnock'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'Fore'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'lift'): 1,
#  HashtagKey(DoM='19', Hour=21, Text=u'Amerika'): 11,
#  HashtagKey(DoM='19', Hour=20, Text=u'WishIWasAtHogwartsSweeps'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'Trends'): 1,
#  HashtagKey(DoM='19', Hour=15, Text=u'MIZ'): 1,
#  HashtagKey(DoM='14', Hour=16, Text=u'JimCrow'): 3,
#  HashtagKey(DoM='19', Hour=19, Text=u'whatsnext'): 1,
#  HashtagKey(DoM='20', Hour=15, Text=u'SportUpdate'): 26,
#  HashtagKey(DoM='20', Hour=14, Text=u'ScreenShot'): 1,
#  HashtagKey(DoM='20', Hour=1, Text=u'StLouis'): 51,
#  HashtagKey(DoM='20', Hour=9, Text=u'Halifax'): 1,
#  HashtagKey(DoM='20', Hour=1, Text=u'MichaelBrownSaturday'): 1,
#  HashtagKey(DoM='20', Hour=23, Text=u'weneedpeace'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'fool'): 1,
#  HashtagKey(DoM='20', Hour=8, Text=u'autopsy'): 1,
#  HashtagKey(DoM='19', Hour=7, Text=u'injustice'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'MamiiGuerrero'): 4,
#  HashtagKey(DoM='20', Hour=10, Text=u'Blackstar'): 1,
#  HashtagKey(DoM='17', Hour=18, Text=u'LETSGETFREE'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'FreshPrince'): 7,
#  HashtagKey(DoM='20', Hour=22, Text=u'drawn'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'BorderCrisis'): 5,
#  HashtagKey(DoM='20', Hour=7, Text=u'AYearInTheLifeOfTheProgressivePatriot'): 3,
#  HashtagKey(DoM='20', Hour=6, Text=u'Repost'): 8,
#  HashtagKey(DoM='14', Hour=17, Text=u'TheHollywoodGossip'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'MediaBiase'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'Microaggressions'): 1,
#  HashtagKey(DoM='20', Hour=20, Text=u'bullion'): 4,
#  HashtagKey(DoM='18', Hour=2, Text=u'TROPA'): 15,
#  HashtagKey(DoM='17', Hour=21, Text=u'prayer'): 3,
#  HashtagKey(DoM='19', Hour=13, Text=u'smem'): 6,
#  HashtagKey(DoM='21', Hour=0, Text=u'JimCrow'): 3,
#  HashtagKey(DoM='20', Hour=5, Text=u'onerace'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'unreliable'): 1,
#  HashtagKey(DoM='19', Hour=21, Text=u'DitchMitch'): 7,
#  HashtagKey(DoM='14', Hour=15, Text=u'DONTSHOOTMEBRO'): 1,
#  HashtagKey(DoM='19', Hour=23, Text=u'Polls'): 5,
#  HashtagKey(DoM='19', Hour=19, Text=u'Nachrichten'): 1,
#  HashtagKey(DoM='20', Hour=23, Text=u'matthews'): 6,
#  HashtagKey(DoM='20', Hour=8, Text=u'nigeria'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'RememberRabaa'): 2,
#  HashtagKey(DoM='14', Hour=21, Text=u'politics'): 29,
#  HashtagKey(DoM='17', Hour=23, Text=u'NationalRoundup'): 1,
#  HashtagKey(DoM='20', Hour=19, Text=u'FergusonThursday'): 1,
#  HashtagKey(DoM='15', Hour=1, Text=u'CT'): 4,
#  HashtagKey(DoM='19', Hour=19, Text=u'foh'): 1,
#  HashtagKey(DoM='20', Hour=15, Text=u'JuniorOrteqa'): 18,
#  HashtagKey(DoM='19', Hour=20, Text=u'YahooNews'): 1,
#  HashtagKey(DoM='18', Hour=5, Text=u'IseeNoChanges'): 1,
#  HashtagKey(DoM='18', Hour=2, Text=u'libtards'): 2,
#  HashtagKey(DoM='20', Hour=0, Text=u'ssu'): 2,
#  HashtagKey(DoM='20', Hour=13, Text=u'Most'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'Standingwithyou'): 6,
#  HashtagKey(DoM='20', Hour=11, Text=u'WhereIsTheFuckingPlane'): 1,
#  HashtagKey(DoM='20', Hour=19, Text=u'FBI'): 27,
#  HashtagKey(DoM='20', Hour=22, Text=u'HighwayPatrolCapt'): 4,
#  HashtagKey(DoM='20', Hour=21, Text=u'Fergusonq'): 1,
#  HashtagKey(DoM='19', Hour=14, Text=u'UGH'): 1,
#  HashtagKey(DoM='20', Hour=5, Text=u'longreads'): 3,
#  HashtagKey(DoM='18', Hour=3, Text=u'FergusonCoverUp'): 1,
#  HashtagKey(DoM='20', Hour=12, Text=u'LouisAreaFoodbank'): 2,
#  HashtagKey(DoM='20', Hour=4, Text=u'getiton'): 1,
#  HashtagKey(DoM='19', Hour=19, Text=u'dagpenge'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'WaterCannons'): 1,
#  HashtagKey(DoM='19', Hour=5, Text=u'haters'): 2,
#  HashtagKey(DoM='20', Hour=9, Text=u'Besiktas'): 6,
#  HashtagKey(DoM='14', Hour=14, Text=u'TyoNews'): 9,
#  HashtagKey(DoM='19', Hour=21, Text=u'Humanity'): 2,
#  HashtagKey(DoM='20', Hour=14, Text=u'dobetter'): 1,
#  HashtagKey(DoM='21', Hour=3, Text=u'RunLoserRun'): 1,
#  HashtagKey(DoM='20', Hour=14, Text=u'Mosul'): 1,
#  HashtagKey(DoM='19', Hour=11, Text=u'WeNeedToSetGoodExamples'): 1,
#  HashtagKey(DoM='20', Hour=20, Text=u'LuismyprivonRD'): 1,
#  HashtagKey(DoM='19', Hour=5, Text=u'STLNativeson'): 1,
#  HashtagKey(DoM='19', Hour=12, Text=u'Teaparty'): 1,
#  HashtagKey(DoM='19', Hour=5, Text=u'prayformissouri'): 1,
#  HashtagKey(DoM='20', Hour=12, Text=u'SoundCloud'): 5,
#  HashtagKey(DoM='20', Hour=23, Text=u'AJOpinion'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'Aug'): 1,
#  HashtagKey(DoM='20', Hour=19, Text=u'A19'): 1,
#  HashtagKey(DoM='19', Hour=12, Text=u'FreeMeekMill'): 3,
#  HashtagKey(DoM='19', Hour=5, Text=u'newblack'): 1,
#  HashtagKey(DoM='20', Hour=7, Text=u'DavidLetterman'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'redeye'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'Marine'): 1,
#  HashtagKey(DoM='19', Hour=10, Text=u'canl\u0131'): 2,
#  HashtagKey(DoM='20', Hour=0, Text=u'uspolitics'): 1,
#  HashtagKey(DoM='20', Hour=12, Text=u'IkybrownUS'): 1,
#  HashtagKey(DoM='20', Hour=16, Text=u'dead'): 2,
#  HashtagKey(DoM='20', Hour=18, Text=u'whiteprivilege'): 2,
#  HashtagKey(DoM='20', Hour=2, Text=u'Sacramento'): 2,
#  HashtagKey(DoM='20', Hour=22, Text=u'IG'): 3,
#  HashtagKey(DoM='15', Hour=3, Text=u'Opencarry'): 1,
#  HashtagKey(DoM='17', Hour=18, Text=u'dogecoin'): 2,
#  HashtagKey(DoM='20', Hour=18, Text=u'Naturals'): 4,
#  HashtagKey(DoM='15', Hour=2, Text=u'QT'): 2,
#  HashtagKey(DoM='19', Hour=20, Text=u'Hilarious'): 2,
#  HashtagKey(DoM='19', Hour=15, Text=u'Houston_0998'): 4,
#  HashtagKey(DoM='20', Hour=5, Text=u'Stunning'): 2,
#  HashtagKey(DoM='19', Hour=19, Text=u'HighwayPatrolCapt'): 1,
#  HashtagKey(DoM='21', Hour=3, Text=u'accounts'): 1,
#  HashtagKey(DoM='20', Hour=23, Text=u'HomelandSecurity'): 1,
#  HashtagKey(DoM='20', Hour=15, Text=u'curious'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'Midnightprotest'): 1,
#  HashtagKey(DoM='19', Hour=9, Text=u'FergusononfireUSA'): 29,
#  HashtagKey(DoM='19', Hour=19, Text=u'NFLF'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'reporting'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'TheDivide'): 15,
#  HashtagKey(DoM='19', Hour=18, Text=u'RapLike'): 2,
#  HashtagKey(DoM='19', Hour=15, Text=u'Civildisobedience'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'SOSEEUU'): 2,
#  HashtagKey(DoM='19', Hour=16, Text=u'teens'): 1,
#  HashtagKey(DoM='19', Hour=15, Text=u'juvenile'): 1,
#  HashtagKey(DoM='20', Hour=12, Text=u'IfTheyGunnedMeDown'): 13,
#  HashtagKey(DoM='20', Hour=15, Text=u'FergusonThunderDome'): 1,
#  HashtagKey(DoM='20', Hour=11, Text=u'cops'): 2,
#  HashtagKey(DoM='15', Hour=3, Text=u'RCDaily'): 2,
#  HashtagKey(DoM='20', Hour=12, Text=u'cdnpoli'): 3,
#  HashtagKey(DoM='19', Hour=23, Text=u'DanteParker'): 19,
#  HashtagKey(DoM='14', Hour=17, Text=u'ServingOrProtecting'): 4,
#  HashtagKey(DoM='15', Hour=1, Text=u'FREEGAZA'): 1,
#  HashtagKey(DoM='17', Hour=23, Text=u'PresidentObama'): 1,
#  HashtagKey(DoM='19', Hour=12, Text=u'R\xe9seauxSociaux'): 1,
#  HashtagKey(DoM='20', Hour=21, Text=u'Justice4MichaelBrown'): 1,
#  HashtagKey(DoM='21', Hour=3, Text=u'cheap'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'protests'): 3,
#  HashtagKey(DoM='19', Hour=14, Text=u'brutality'): 3,
#  HashtagKey(DoM='14', Hour=21, Text=u'VatterottCollege'): 1,
#  HashtagKey(DoM='20', Hour=3, Text=u'TooBigToTrust'): 2,
#  HashtagKey(DoM='14', Hour=15, Text=u'oversight'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'FergusonRiot'): 172,
#  HashtagKey(DoM='19', Hour=15, Text=u'NYC'): 16,
#  HashtagKey(DoM='19', Hour=19, Text=u'accountibility'): 1,
#  HashtagKey(DoM='20', Hour=14, Text=u'BlackonBlackCrime'): 5,
#  HashtagKey(DoM='20', Hour=3, Text=u'Solidarity'): 4,
#  HashtagKey(DoM='20', Hour=17, Text=u'StayHuman'): 1,
#  HashtagKey(DoM='19', Hour=23, Text=u'RaceWar'): 2,
#  HashtagKey(DoM='19', Hour=19, Text=u'Sign'): 1,
#  HashtagKey(DoM='14', Hour=16, Text=u'stateviolence'): 1,
#  HashtagKey(DoM='19', Hour=15, Text=u'incongruity'): 1,
#  HashtagKey(DoM='21', Hour=0, Text=u'AntMan'): 3,
#  HashtagKey(DoM='19', Hour=15, Text=u'JusticeforMikeBrown'): 33,
#  HashtagKey(DoM='18', Hour=2, Text=u'Witness'): 1,
#  HashtagKey(DoM='19', Hour=14, Text=u'GilScott'): 1,
#  HashtagKey(DoM='17', Hour=21, Text=u'BlackChurches'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'NoHandouts'): 1,
#  HashtagKey(DoM='18', Hour=5, Text=u'CaptJohnson'): 3,
#  HashtagKey(DoM='20', Hour=6, Text=u'nyc'): 1,
#  HashtagKey(DoM='17', Hour=23, Text=u'ClarkAtlanta'): 1,
#  HashtagKey(DoM='15', Hour=1, Text=u'hotnews'): 1,
#  HashtagKey(DoM='17', Hour=20, Text=u'social'): 1,
#  HashtagKey(DoM='19', Hour=9, Text=u'730abc'): 1,
#  HashtagKey(DoM='14', Hour=15, Text=u'AskTwitter'): 3,
#  HashtagKey(DoM='20', Hour=19, Text=u'justiceforemikebrown'): 3,
#  HashtagKey(DoM='20', Hour=20, Text=u'good'): 1,
#  HashtagKey(DoM='19', Hour=6, Text=u'lapalma'): 1,
#  HashtagKey(DoM='15', Hour=7, Text=u'FPD'): 1,
#  HashtagKey(DoM='14', Hour=17, Text=u'Fordham'): 1,
#  HashtagKey(DoM='20', Hour=14, Text=u'FergusonSolidarity'): 1,
#  HashtagKey(DoM='20', Hour=19, Text=u'postal'): 1,
#  HashtagKey(DoM='20', Hour=11, Text=u'DesMoinesNews'): 1,
#  HashtagKey(DoM='20', Hour=23, Text=u'POS'): 5,
#  HashtagKey(DoM='15', Hour=2, Text=u'ericgarner'): 3,
#  HashtagKey(DoM='21', Hour=0, Text=u'BloodOnTheirHands'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'JonSwaine'): 1,
#  HashtagKey(DoM='20', Hour=0, Text=u'bishopEdwinBass'): 1,
#  HashtagKey(DoM='18', Hour=5, Text=u'mediablackout'): 12,
#  HashtagKey(DoM='20', Hour=9, Text=u'by0'): 1,
#  HashtagKey(DoM='21', Hour=2, Text=u'HSV'): 1,
#  HashtagKey(DoM='19', Hour=12, Text=u'MorningFeature'): 2,
#  HashtagKey(DoM='17', Hour=21, Text=u'burma'): 1,
#  HashtagKey(DoM='21', Hour=2, Text=u'EternalLifeProject'): 1,
#  HashtagKey(DoM='19', Hour=8, Text=u'humanitarian'): 1,
#  HashtagKey(DoM='14', Hour=21, Text=u'STFU'): 2,
#  HashtagKey(DoM='19', Hour=14, Text=u'Pentagon'): 1,
#  HashtagKey(DoM='14', Hour=21, Text=u'NoMorePoliceStates'): 1,
#  HashtagKey(DoM='14', Hour=16, Text=u'Azerbaijan'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'StandWithFergusonMo'): 1,
#  HashtagKey(DoM='15', Hour=1, Text=u'idea'): 1,
#  HashtagKey(DoM='20', Hour=22, Text=u'religion'): 1,
#  HashtagKey(DoM='20', Hour=10, Text=u'ovii_starz'): 4,
#  HashtagKey(DoM='20', Hour=0, Text=u'StopTheBlameGame'): 1,
#  HashtagKey(DoM='19', Hour=19, Text=u'CCSS'): 1,
#  HashtagKey(DoM='19', Hour=21, Text=u'politie'): 2,
#  HashtagKey(DoM='17', Hour=23, Text=u'AmericaTonight'): 1,
#  HashtagKey(DoM='20', Hour=4, Text=u'prayer'): 2,
#  HashtagKey(DoM='21', Hour=3, Text=u'WTFwevote'): 1,
#  HashtagKey(DoM='19', Hour=11, Text=u'unjustifiedandexcessive'): 1,
#  HashtagKey(DoM='17', Hour=21, Text=u'BruceOWayne'): 1,
#  HashtagKey(DoM='20', Hour=9, Text=u'M5S'): 4,
#  HashtagKey(DoM='15', Hour=9, Text=u'lies'): 3,
#  HashtagKey(DoM='20', Hour=17, Text=u'UnitedStates'): 2,
#  HashtagKey(DoM='20', Hour=18, Text=u'tactical'): 1,
#  HashtagKey(DoM='20', Hour=21, Text=u'copsaregangs'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'jawDropping'): 1,
#  HashtagKey(DoM='19', Hour=7, Text=u'DONTSHOOT'): 8,
#  HashtagKey(DoM='19', Hour=19, Text=u'Miami'): 9,
#  HashtagKey(DoM='14', Hour=14, Text=u'EU'): 6,
#  HashtagKey(DoM='18', Hour=4, Text=u'xxx'): 2,
#  HashtagKey(DoM='17', Hour=17, Text=u'FoxNews'): 4,
#  HashtagKey(DoM='20', Hour=23, Text=u'SeanBell'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'FOTOS'): 1,
#  HashtagKey(DoM='14', Hour=16, Text=u'legalnews'): 1,
#  HashtagKey(DoM='15', Hour=10, Text=u'uniteblue'): 5,
#  HashtagKey(DoM='20', Hour=15, Text=u'SanBernardinoNews'): 1,
#  HashtagKey(DoM='20', Hour=12, Text=u'message'): 2,
#  HashtagKey(DoM='15', Hour=0, Text=u'PtSafety'): 12,
#  HashtagKey(DoM='19', Hour=18, Text=u'EricGarner'): 21,
#  HashtagKey(DoM='19', Hour=14, Text=u'stayconnected'): 1,
#  HashtagKey(DoM='20', Hour=20, Text=u'VoterRegistration'): 1,
#  HashtagKey(DoM='20', Hour=0, Text=u'Lice'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'RIPRobinWilliams'): 1,
#  HashtagKey(DoM='20', Hour=4, Text=u'White'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'MA'): 1,
#  HashtagKey(DoM='19', Hour=5, Text=u'NCAT18'): 8,
#  HashtagKey(DoM='21', Hour=0, Text=u'PowellShooting'): 1,
#  HashtagKey(DoM='20', Hour=20, Text=u'peacefulprotest'): 6,
#  HashtagKey(DoM='14', Hour=21, Text=u'aj'): 1,
#  HashtagKey(DoM='21', Hour=0, Text=u'PantsUpDontLoot'): 1,
#  HashtagKey(DoM='15', Hour=0, Text=u'2a'): 1,
#  HashtagKey(DoM='20', Hour=12, Text=u'People'): 2,
#  HashtagKey(DoM='17', Hour=20, Text=u'ridiculous'): 1,
#  HashtagKey(DoM='14', Hour=17, Text=u'black'): 2,
#  HashtagKey(DoM='20', Hour=2, Text=u'shoutout'): 1,
#  HashtagKey(DoM='19', Hour=14, Text=u'edtechchat'): 1,
#  HashtagKey(DoM='15', Hour=0, Text=u'BlackActivist'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'HeIsInHellNow'): 2,
#  HashtagKey(DoM='17', Hour=23, Text=u'noticias'): 1,
#  HashtagKey(DoM='19', Hour=19, Text=u'mix'): 1,
#  HashtagKey(DoM='20', Hour=22, Text=u'sexism'): 1,
#  HashtagKey(DoM='19', Hour=12, Text=u'thugs'): 7,
#  HashtagKey(DoM='20', Hour=11, Text=u'by0'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'Morons'): 2,
#  HashtagKey(DoM='17', Hour=21, Text=u'London'): 8,
#  HashtagKey(DoM='19', Hour=23, Text=u'rickperry2016'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'border'): 1,
#  HashtagKey(DoM='19', Hour=7, Text=u'JasonBentley'): 2,
#  HashtagKey(DoM='14', Hour=17, Text=u'policestate'): 199,
#  HashtagKey(DoM='20', Hour=11, Text=u'RIPJamesFoley'): 2,
#  HashtagKey(DoM='19', Hour=12, Text=u'SWAT'): 2,
#  HashtagKey(DoM='19', Hour=19, Text=u'ANGELCHALLENGE'): 14,
#  HashtagKey(DoM='20', Hour=7, Text=u'crazy'): 1,
#  HashtagKey(DoM='19', Hour=23, Text=u'nrainferguson'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'MindBlown'): 1,
#  HashtagKey(DoM='19', Hour=8, Text=u'America'): 21,
#  HashtagKey(DoM='18', Hour=3, Text=u'MrCharlie'): 1,
#  HashtagKey(DoM='18', Hour=0, Text=u'manyriverspbs'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'Unethical'): 1,
#  HashtagKey(DoM='20', Hour=22, Text=u'wagwan'): 2,
#  HashtagKey(DoM='20', Hour=14, Text=u'MFvision'): 1,
#  HashtagKey(DoM='20', Hour=23, Text=u'greta'): 1,
#  HashtagKey(DoM='17', Hour=19, Text=u'mediablackout'): 7,
#  HashtagKey(DoM='14', Hour=15, Text=u'CCOT'): 1,
#  HashtagKey(DoM='19', Hour=8, Text=u'GOTV'): 1,
#  HashtagKey(DoM='20', Hour=11, Text=u'Music'): 1,
#  HashtagKey(DoM='19', Hour=16, Text=u'libs'): 2,
#  HashtagKey(DoM='20', Hour=13, Text=u'icebucketchallange'): 1,
#  HashtagKey(DoM='20', Hour=22, Text=u'Revenge'): 3,
#  HashtagKey(DoM='19', Hour=19, Text=u'AssholeCops'): 1,
#  HashtagKey(DoM='14', Hour=18, Text=u'ourlivesmatter'): 4,
#  HashtagKey(DoM='19', Hour=11, Text=u'israel'): 3,
#  HashtagKey(DoM='19', Hour=18, Text=u'BlackEmpowerment'): 1,
#  HashtagKey(DoM='20', Hour=10, Text=u'DontMug'): 1,
#  HashtagKey(DoM='20', Hour=4, Text=u'SpikeLee'): 3,
#  HashtagKey(DoM='15', Hour=2, Text=u'KKKrally'): 1,
#  HashtagKey(DoM='20', Hour=21, Text=u'blocktheboat'): 2,
#  HashtagKey(DoM='19', Hour=15, Text=u'49ers'): 1,
#  HashtagKey(DoM='18', Hour=1, Text=u'liberals'): 2,
#  HashtagKey(DoM='19', Hour=20, Text=u'EricGarner'): 27,
#  HashtagKey(DoM='19', Hour=21, Text=u'Science'): 1,
#  HashtagKey(DoM='19', Hour=5, Text=u'Internacional'): 3,
#  HashtagKey(DoM='17', Hour=22, Text=u'JusticeForTrayvon'): 11,
#  HashtagKey(DoM='20', Hour=21, Text=u'racialjustice'): 1,
#  HashtagKey(DoM='19', Hour=14, Text=u'malikshabazz'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'Khaatumo'): 5,
#  HashtagKey(DoM='20', Hour=2, Text=u'UnionSquare'): 45,
#  HashtagKey(DoM='21', Hour=0, Text=u'ThisJustIn'): 2,
#  HashtagKey(DoM='20', Hour=20, Text=u'look'): 1,
#  HashtagKey(DoM='19', Hour=5, Text=u'TheSixties'): 3,
#  HashtagKey(DoM='19', Hour=23, Text=u'economics'): 2,
#  HashtagKey(DoM='18', Hour=2, Text=u'sorrynotsorry'): 2,
#  HashtagKey(DoM='20', Hour=21, Text=u'firstnations'): 1,
#  HashtagKey(DoM='19', Hour=12, Text=u'Seattle'): 2,
#  HashtagKey(DoM='19', Hour=21, Text=u'inequality'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'DONTPANIC'): 1,
#  HashtagKey(DoM='17', Hour=20, Text=u'MutualAid'): 2,
#  HashtagKey(DoM='14', Hour=14, Text=u'World'): 1,
#  HashtagKey(DoM='19', Hour=16, Text=u'bloodywellriot'): 1,
#  HashtagKey(DoM='21', Hour=2, Text=u'apartheid'): 1,
#  HashtagKey(DoM='14', Hour=15, Text=u'OccupyFerguson'): 42,
#  HashtagKey(DoM='17', Hour=22, Text=u'ozarks'): 2,
#  HashtagKey(DoM='17', Hour=20, Text=u'StandUpForPeace'): 1,
#  HashtagKey(DoM='19', Hour=11, Text=u'Shooting'): 1,
#  HashtagKey(DoM='20', Hour=10, Text=u'BlueWave2014'): 3,
#  HashtagKey(DoM='19', Hour=7, Text=u'StopTheBloodshed'): 2,
#  HashtagKey(DoM='19', Hour=21, Text=u'Halifax'): 71,
#  HashtagKey(DoM='20', Hour=15, Text=u'AmericasHorrorStory'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'amagi'): 1,
#  HashtagKey(DoM='19', Hour=21, Text=u'WakeUpAmerica'): 2,
#  HashtagKey(DoM='20', Hour=21, Text=u'FergusonPD'): 23,
#  HashtagKey(DoM='20', Hour=2, Text=u'fuckthe5'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'coloniality'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'WhitePrivilege'): 16,
#  HashtagKey(DoM='14', Hour=14, Text=u'ComeLord'): 1,
#  HashtagKey(DoM='19', Hour=11, Text=u'MakeMeWannaHoller'): 1,
#  HashtagKey(DoM='20', Hour=5, Text=u'whodoyouprotect'): 2,
#  HashtagKey(DoM='14', Hour=20, Text=u'Nixon'): 6,
#  HashtagKey(DoM='19', Hour=20, Text=u'Jaketapper'): 2,
#  HashtagKey(DoM='20', Hour=4, Text=u'Blocked'): 1,
#  HashtagKey(DoM='20', Hour=15, Text=u'Golf'): 2,
#  HashtagKey(DoM='19', Hour=5, Text=u'buycott'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'controlacrisi'): 5,
#  HashtagKey(DoM='20', Hour=14, Text=u'DonLemon'): 4,
#  HashtagKey(DoM='20', Hour=11, Text=u'wilson'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'QuitSmoking'): 2,
#  HashtagKey(DoM='19', Hour=15, Text=u'interraciallove'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'FR'): 1,
#  HashtagKey(DoM='14', Hour=21, Text=u'EnlightenMe'): 1,
#  HashtagKey(DoM='19', Hour=8, Text=u'FamiilyPretty'): 4,
#  HashtagKey(DoM='19', Hour=7, Text=u'family'): 2,
#  HashtagKey(DoM='20', Hour=10, Text=u'BorderCrisis'): 2,
#  HashtagKey(DoM='19', Hour=14, Text=u'Salute'): 5,
#  HashtagKey(DoM='19', Hour=18, Text=u'Oakland'): 2,
#  HashtagKey(DoM='20', Hour=19, Text=u'MUFC'): 2,
#  HashtagKey(DoM='19', Hour=5, Text=u'savethemoney'): 1,
#  HashtagKey(DoM='20', Hour=22, Text=u'RamosFerguson'): 4,
#  HashtagKey(DoM='20', Hour=3, Text=u'Nigger'): 1,
#  HashtagKey(DoM='19', Hour=23, Text=u'patriots'): 2,
#  HashtagKey(DoM='20', Hour=22, Text=u'Characters'): 1,
#  HashtagKey(DoM='20', Hour=11, Text=u'PierrePD'): 2,
#  HashtagKey(DoM='20', Hour=14, Text=u'quit'): 1,
#  HashtagKey(DoM='19', Hour=11, Text=u'umsl'): 1,
#  HashtagKey(DoM='20', Hour=13, Text=u'UN'): 1,
#  HashtagKey(DoM='17', Hour=22, Text=u'WarMachine'): 1,
#  HashtagKey(DoM='17', Hour=21, Text=u'EnEspa\xf1ol'): 1,
#  HashtagKey(DoM='20', Hour=9, Text=u'BarakaObama'): 3,
#  HashtagKey(DoM='20', Hour=11, Text=u'Yugadu'): 3,
#  HashtagKey(DoM='14', Hour=17, Text=u'Viral'): 1,
#  HashtagKey(DoM='19', Hour=8, Text=u'Obamasamerica'): 2,
#  HashtagKey(DoM='20', Hour=4, Text=u'StatesRightsYALL'): 4,
#  HashtagKey(DoM='17', Hour=22, Text=u'community'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'Support'): 2,
#  HashtagKey(DoM='14', Hour=21, Text=u'auspol'): 8,
#  HashtagKey(DoM='19', Hour=14, Text=u'welfare'): 11,
#  HashtagKey(DoM='19', Hour=20, Text=u'selfie'): 1,
#  HashtagKey(DoM='19', Hour=13, Text=u'KnockoutGame'): 2,
#  HashtagKey(DoM='20', Hour=0, Text=u'Discriminaci\xf3nRacial'): 15,
#  HashtagKey(DoM='20', Hour=5, Text=u'nwo'): 1,
#  HashtagKey(DoM='14', Hour=21, Text=u'Congress'): 2,
#  HashtagKey(DoM='20', Hour=5, Text=u'Mundo'): 1,
#  HashtagKey(DoM='19', Hour=15, Text=u'OperationHelpOrHush'): 5,
#  HashtagKey(DoM='20', Hour=1, Text=u'KevinFrezhx3'): 1,
#  HashtagKey(DoM='20', Hour=22, Text=u'Dotheythinkwearestupid'): 1,
#  HashtagKey(DoM='18', Hour=5, Text=u'Cairo'): 1,
#  HashtagKey(DoM='20', Hour=22, Text=u'monde'): 2,
#  HashtagKey(DoM='19', Hour=13, Text=u'POLICE'): 4,
#  HashtagKey(DoM='20', Hour=12, Text=u'\ub3c5\ub9bd\uc6b4\ub3d9\uac00'): 1,
#  HashtagKey(DoM='20', Hour=20, Text=u'TrayvonMartin'): 30,
#  HashtagKey(DoM='20', Hour=8, Text=u'height'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'PumpkinFestival'): 1,
#  HashtagKey(DoM='18', Hour=5, Text=u'KruiserFeelings'): 5,
#  HashtagKey(DoM='19', Hour=12, Text=u'disgusted'): 5,
#  HashtagKey(DoM='19', Hour=20, Text=u'AlMinuto'): 2,
#  HashtagKey(DoM='20', Hour=19, Text=u'JusticeforMichaelBrown'): 4,
#  HashtagKey(DoM='19', Hour=19, Text=u'mo'): 1,
#  HashtagKey(DoM='17', Hour=23, Text=u'EthnicCleansing'): 4,
#  HashtagKey(DoM='19', Hour=8, Text=u'influence'): 2,
#  HashtagKey(DoM='20', Hour=3, Text=u'CleanWater'): 2,
#  HashtagKey(DoM='21', Hour=3, Text=u'JonathanShorman'): 1,
#  HashtagKey(DoM='17', Hour=19, Text=u'HowardBeach'): 1,
#  HashtagKey(DoM='20', Hour=3, Text=u'SethStoughton'): 1,
#  HashtagKey(DoM='14', Hour=21, Text=u'policestate'): 41,
#  HashtagKey(DoM='19', Hour=9, Text=u'1AMNewsKS'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'Vote2014'): 2,
#  HashtagKey(DoM='19', Hour=15, Text=u'travel'): 3,
#  HashtagKey(DoM='20', Hour=3, Text=u'Genocide'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'FederalInvestigation'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'fucktards'): 4,
#  HashtagKey(DoM='15', Hour=2, Text=u'AmessagefromISIStoUS'): 2,
#  HashtagKey(DoM='19', Hour=16, Text=u'askdarrenwilson'): 3,
#  HashtagKey(DoM='20', Hour=2, Text=u'Guerrero_x5'): 1,
#  HashtagKey(DoM='20', Hour=13, Text=u'Revolution'): 1,
#  HashtagKey(DoM='15', Hour=7, Text=u'VotingRightsAct'): 1,
#  HashtagKey(DoM='20', Hour=3, Text=u'KeepStayingStrong'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'demonstrator'): 7,
#  HashtagKey(DoM='19', Hour=7, Text=u'fake'): 2,
#  HashtagKey(DoM='15', Hour=7, Text=u'partest'): 1,
#  HashtagKey(DoM='20', Hour=3, Text=u'SomethingToThinkAbout'): 1,
#  HashtagKey(DoM='21', Hour=0, Text=u'MoNe'): 1,
#  HashtagKey(DoM='17', Hour=19, Text=u'LidovkySv\u011bt'): 1,
#  HashtagKey(DoM='14', Hour=17, Text=u'triggerhappy'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'fox'): 1,
#  HashtagKey(DoM='14', Hour=15, Text=u'justiceformichaelbrown'): 1,
#  HashtagKey(DoM='20', Hour=8, Text=u'nrl'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'countyprocecutor'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'EverettCollection'): 2,
#  HashtagKey(DoM='15', Hour=3, Text=u'AsOne'): 1,
#  HashtagKey(DoM='14', Hour=15, Text=u'Millennials'): 1,
#  HashtagKey(DoM='19', Hour=15, Text=u'Look'): 1,
#  HashtagKey(DoM='20', Hour=0, Text=u'IS'): 8,
#  HashtagKey(DoM='15', Hour=1, Text=u'wth'): 1,
#  HashtagKey(DoM='20', Hour=11, Text=u'GazaUnderAttack'): 20,
#  HashtagKey(DoM='14', Hour=15, Text=u'speakup'): 3,
#  HashtagKey(DoM='19', Hour=22, Text=u'WarWithin'): 1,
#  HashtagKey(DoM='20', Hour=20, Text=u'Aus'): 1,
#  HashtagKey(DoM='20', Hour=23, Text=u'OWSinfo'): 3,
#  HashtagKey(DoM='19', Hour=5, Text=u'speechless'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'Sovereignty'): 2,
#  HashtagKey(DoM='18', Hour=0, Text=u'Hate'): 3,
#  HashtagKey(DoM='18', Hour=1, Text=u'CharlieRiedel'): 1,
#  HashtagKey(DoM='14', Hour=20, Text=u'FakePressConference'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'policestate'): 31,
#  HashtagKey(DoM='20', Hour=7, Text=u'KMOV'): 6,
#  HashtagKey(DoM='20', Hour=16, Text=u'MilitarizationOfPolice'): 6,
#  HashtagKey(DoM='20', Hour=16, Text=u'Peaceful'): 2,
#  HashtagKey(DoM='18', Hour=4, Text=u'Fergusonlivestream'): 1,
#  HashtagKey(DoM='20', Hour=23, Text=u'troll'): 1,
#  HashtagKey(DoM='14', Hour=17, Text=u'corporate'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'arrestthepolice'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'Mikebrown'): 36,
#  HashtagKey(DoM='19', Hour=22, Text=u'college'): 2,
#  HashtagKey(DoM='17', Hour=18, Text=u'lgbt'): 11,
#  HashtagKey(DoM='19', Hour=6, Text=u'Army'): 5,
#  HashtagKey(DoM='20', Hour=0, Text=u'latism'): 3,
#  HashtagKey(DoM='20', Hour=16, Text=u'occupation'): 1,
#  HashtagKey(DoM='20', Hour=8, Text=u'BangBang'): 1,
#  HashtagKey(DoM='19', Hour=19, Text=u'mikebrown'): 210,
#  HashtagKey(DoM='18', Hour=5, Text=u'michaelbrownshooting'): 2,
#  HashtagKey(DoM='20', Hour=3, Text=u'blessTheirHearts'): 2,
#  HashtagKey(DoM='18', Hour=1, Text=u'DarianAlcantara'): 2,
#  HashtagKey(DoM='17', Hour=18, Text=u'ComeTogether'): 1,
#  HashtagKey(DoM='14', Hour=23, Text=u'JimRisen'): 1,
#  HashtagKey(DoM='19', Hour=6, Text=u'wiunion'): 4,
#  HashtagKey(DoM='19', Hour=6, Text=u'Tibet'): 4,
#  HashtagKey(DoM='20', Hour=13, Text=u'westboro'): 1,
#  HashtagKey(DoM='15', Hour=0, Text=u'unl'): 2,
#  HashtagKey(DoM='20', Hour=23, Text=u'LaMortLeurVaSiBien'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'opencarry'): 1,
#  HashtagKey(DoM='21', Hour=3, Text=u'TooPIGtoJAIL'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'\u0623\u062e\u0628\u0627\u0631'): 1,
#  HashtagKey(DoM='20', Hour=16, Text=u'excellent'): 1,
#  HashtagKey(DoM='15', Hour=1, Text=u'MikeBrownNOLA'): 2,
#  HashtagKey(DoM='19', Hour=18, Text=u'TeamTwitter'): 1,
#  HashtagKey(DoM='18', Hour=2, Text=u'edtech'): 1,
#  HashtagKey(DoM='14', Hour=15, Text=u'hypocrisy'): 2,
#  HashtagKey(DoM='20', Hour=3, Text=u'Boston'): 9,
#  HashtagKey(DoM='21', Hour=2, Text=u'throwbackthursday'): 1,
#  HashtagKey(DoM='20', Hour=9, Text=u'Google'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'copsdontprotectshit'): 1,
#  HashtagKey(DoM='19', Hour=8, Text=u'Tistory'): 1,
#  HashtagKey(DoM='18', Hour=2, Text=u'torn'): 1,
#  HashtagKey(DoM='19', Hour=21, Text=u'JusticeForTrayvon'): 5,
#  HashtagKey(DoM='19', Hour=14, Text=u'ABQs'): 1,
#  HashtagKey(DoM='20', Hour=18, Text=u'UK'): 8,
#  HashtagKey(DoM='17', Hour=18, Text=u'CornellWilliamBrooks'): 4,
#  HashtagKey(DoM='20', Hour=12, Text=u'Ebola'): 45,
#  HashtagKey(DoM='17', Hour=22, Text=u'WICKED'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'BeReal'): 1,
#  HashtagKey(DoM='20', Hour=22, Text=u'NegroSpring'): 1,
#  HashtagKey(DoM='20', Hour=9, Text=u'WorldRSSFeeds'): 1,
#  HashtagKey(DoM='20', Hour=9, Text=u'BCA_Ritzy'): 1,
#  HashtagKey(DoM='20', Hour=3, Text=u'LittleRock'): 1,
#  HashtagKey(DoM='21', Hour=2, Text=u'HUMANrace'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'fuckamerica'): 1,
#  HashtagKey(DoM='20', Hour=0, Text=u'Spikelee'): 1,
#  HashtagKey(DoM='18', Hour=5, Text=u'SocialJusticeGnomes'): 1,
#  HashtagKey(DoM='20', Hour=21, Text=u'America'): 7,
#  HashtagKey(DoM='20', Hour=9, Text=u'EDL'): 1,
#  HashtagKey(DoM='20', Hour=7, Text=u'PrayforPeace'): 1,
#  HashtagKey(DoM='18', Hour=2, Text=u'conflict'): 1,
#  HashtagKey(DoM='20', Hour=1, Text=u'Presidential'): 1,
#  HashtagKey(DoM='17', Hour=22, Text=u'ocra'): 2,
#  HashtagKey(DoM='17', Hour=19, Text=u'BrianSchellman'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'lifestyle'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'HearsayPolitics'): 1,
#  HashtagKey(DoM='19', Hour=17, Text=u'News'): 123,
#  HashtagKey(DoM='14', Hour=14, Text=u'oladeile'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'WillfulBlindness'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'sheeple'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'aferguiraq'): 3,
#  HashtagKey(DoM='19', Hour=14, Text=u'EndAmericanIdiocy'): 2,
#  HashtagKey(DoM='20', Hour=1, Text=u'followforfollow'): 1,
#  HashtagKey(DoM='20', Hour=16, Text=u'BLACKOUT'): 1,
#  HashtagKey(DoM='19', Hour=9, Text=u'TKT'): 3,
#  HashtagKey(DoM='20', Hour=1, Text=u'Fergurson'): 1,
#  HashtagKey(DoM='20', Hour=21, Text=u'Camron'): 1,
#  HashtagKey(DoM='20', Hour=21, Text=u'UnionJLive'): 1,
#  HashtagKey(DoM='19', Hour=19, Text=u'Real'): 4,
#  HashtagKey(DoM='20', Hour=4, Text=u'GazaUnderAtack'): 1,
#  HashtagKey(DoM='17', Hour=22, Text=u'idol'): 2,
#  HashtagKey(DoM='19', Hour=5, Text=u'kissasses'): 1,
#  HashtagKey(DoM='20', Hour=3, Text=u'recalljaynixon'): 2,
#  HashtagKey(DoM='19', Hour=5, Text=u'JusticForAllAmerican'): 1,
#  HashtagKey(DoM='19', Hour=6, Text=u'PALESTINE'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'law_enforcement'): 1,
#  HashtagKey(DoM='17', Hour=19, Text=u'KY'): 3,
#  HashtagKey(DoM='19', Hour=10, Text=u'newsnight'): 1,
#  HashtagKey(DoM='19', Hour=12, Text=u'nowplaying'): 2,
#  HashtagKey(DoM='20', Hour=22, Text=u'CaptainJohnson'): 3,
#  HashtagKey(DoM='19', Hour=12, Text=u'graffiti'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'florida'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'blackpride'): 22,
#  HashtagKey(DoM='19', Hour=22, Text=u'blog'): 2,
#  HashtagKey(DoM='20', Hour=14, Text=u'LaIguanaTv'): 1,
#  HashtagKey(DoM='14', Hour=16, Text=u'FUCKMSM'): 1,
#  HashtagKey(DoM='20', Hour=15, Text=u'HandsUp'): 87,
#  HashtagKey(DoM='20', Hour=2, Text=u'Psalms29'): 1,
#  HashtagKey(DoM='17', Hour=20, Text=u'GazaUnderAttack'): 19,
#  HashtagKey(DoM='19', Hour=11, Text=u'jerdchat'): 3,
#  HashtagKey(DoM='20', Hour=18, Text=u'whatshot'): 2,
#  HashtagKey(DoM='19', Hour=17, Text=u'holyshit'): 1,
#  HashtagKey(DoM='18', Hour=2, Text=u'foia'): 1,
#  HashtagKey(DoM='20', Hour=23, Text=u'HipHopEastCoast'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'worldpeace'): 1,
#  HashtagKey(DoM='17', Hour=22, Text=u'RealEstate'): 2,
#  HashtagKey(DoM='19', Hour=23, Text=u'goodmusic'): 1,
#  HashtagKey(DoM='19', Hour=11, Text=u'Citizens'): 2,
#  HashtagKey(DoM='19', Hour=16, Text=u'Austria'): 2,
#  HashtagKey(DoM='19', Hour=21, Text=u'\xc9bolaVirus'): 1,
#  HashtagKey(DoM='19', Hour=20, Text=u'gasmasks'): 7,
#  HashtagKey(DoM='20', Hour=14, Text=u'HedyEpstein'): 5,
#  HashtagKey(DoM='17', Hour=20, Text=u'BlackEmpowerment'): 1,
#  HashtagKey(DoM='17', Hour=21, Text=u'WIunion'): 1,
#  HashtagKey(DoM='21', Hour=2, Text=u'Isis'): 2,
#  HashtagKey(DoM='21', Hour=0, Text=u'Doh'): 2,
#  HashtagKey(DoM='19', Hour=23, Text=u'BO'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'Holdon'): 1,
#  HashtagKey(DoM='20', Hour=13, Text=u'ColourBlind'): 1,
#  HashtagKey(DoM='15', Hour=10, Text=u'institutions'): 1,
#  HashtagKey(DoM='20', Hour=15, Text=u'StandWithWilson'): 1,
#  HashtagKey(DoM='20', Hour=0, Text=u'Protest'): 8,
#  HashtagKey(DoM='18', Hour=5, Text=u'RedNationRising'): 2,
#  HashtagKey(DoM='14', Hour=15, Text=u'veterans'): 1,
#  HashtagKey(DoM='19', Hour=14, Text=u'intelligence'): 1,
#  HashtagKey(DoM='19', Hour=16, Text=u'CallForJustice'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'Justin'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'indy'): 50,
#  HashtagKey(DoM='14', Hour=14, Text=u'USnews'): 2,
#  HashtagKey(DoM='20', Hour=2, Text=u'peacefulprotest'): 4,
#  HashtagKey(DoM='19', Hour=11, Text=u'censured'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'nosleep'): 1,
#  HashtagKey(DoM='15', Hour=2, Text=u'NDN'): 2,
#  HashtagKey(DoM='19', Hour=22, Text=u'swangin'): 3,
#  HashtagKey(DoM='18', Hour=0, Text=u'Memphis'): 6,
#  HashtagKey(DoM='20', Hour=3, Text=u'PEACEFUL'): 1,
#  HashtagKey(DoM='15', Hour=1, Text=u'WhereIsTheFuckingPlane'): 3,
#  HashtagKey(DoM='15', Hour=3, Text=u'LAPD'): 8,
#  HashtagKey(DoM='20', Hour=23, Text=u'StayStrapped'): 2,
#  HashtagKey(DoM='18', Hour=0, Text=u'WY'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'Hillary'): 1,
#  HashtagKey(DoM='20', Hour=14, Text=u'DetroitFreePress'): 1,
#  HashtagKey(DoM='18', Hour=4, Text=u'FireSale'): 4,
#  HashtagKey(DoM='19', Hour=20, Text=u'IS'): 2,
#  HashtagKey(DoM='14', Hour=14, Text=u'Woodlands'): 2,
#  HashtagKey(DoM='20', Hour=8, Text=u'Am\xe9riques'): 1,
#  HashtagKey(DoM='19', Hour=18, Text=u'NL1'): 1,
#  HashtagKey(DoM='20', Hour=11, Text=u'pointofview'): 1,
#  HashtagKey(DoM='20', Hour=20, Text=u'MUFC'): 16,
#  HashtagKey(DoM='20', Hour=3, Text=u'WarOnDrugs'): 1,
#  HashtagKey(DoM='20', Hour=16, Text=u'SHOT'): 3,
#  HashtagKey(DoM='18', Hour=3, Text=u'WheresCaptJohnson'): 1,
#  HashtagKey(DoM='19', Hour=17, Text=u'OOH'): 2,
#  HashtagKey(DoM='17', Hour=20, Text=u's95'): 1,
#  HashtagKey(DoM='21', Hour=3, Text=u'DemBringinMoMurda'): 3,
#  HashtagKey(DoM='20', Hour=18, Text=u'stlarts'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'painting'): 2,
#  HashtagKey(DoM='20', Hour=23, Text=u'AlMomento'): 2,
#  HashtagKey(DoM='20', Hour=17, Text=u'up3sn'): 1,
#  HashtagKey(DoM='18', Hour=3, Text=u'Kerry'): 1,
#  HashtagKey(DoM='20', Hour=5, Text=u'bigboypants'): 1,
#  HashtagKey(DoM='20', Hour=22, Text=u'ChrisHayes'): 5,
#  HashtagKey(DoM='20', Hour=4, Text=u'NateDogg'): 1,
#  HashtagKey(DoM='20', Hour=7, Text=u'ProTip'): 1,
#  HashtagKey(DoM='19', Hour=12, Text=u'LibCrib'): 14,
#  HashtagKey(DoM='15', Hour=9, Text=u'alternet'): 2,
#  HashtagKey(DoM='17', Hour=21, Text=u'Milwaukee'): 27,
#  HashtagKey(DoM='20', Hour=5, Text=u'ArgusRadio'): 2,
#  HashtagKey(DoM='15', Hour=0, Text=u'AllOurDaughters'): 1,
#  HashtagKey(DoM='14', Hour=15, Text=u'BizTrend'): 1,
#  HashtagKey(DoM='20', Hour=13, Text=u'GentleGiant'): 2,
#  HashtagKey(DoM='15', Hour=2, Text=u'Like'): 2,
#  HashtagKey(DoM='19', Hour=21, Text=u'Trending'): 4,
#  HashtagKey(DoM='20', Hour=20, Text=u'twitter'): 3,
#  HashtagKey(DoM='20', Hour=3, Text=u'socialmedia'): 8,
#  HashtagKey(DoM='19', Hour=20, Text=u'sketchy'): 1,
#  HashtagKey(DoM='18', Hour=2, Text=u'\uc138\uc6d4\ud638'): 1,
#  HashtagKey(DoM='19', Hour=14, Text=u'ALSIceBucketChallenge'): 8,
#  HashtagKey(DoM='20', Hour=6, Text=u'photography'): 4,
#  HashtagKey(DoM='20', Hour=2, Text=u'women'): 1,
#  HashtagKey(DoM='20', Hour=2, Text=u'VENEZUELA'): 11,
#  HashtagKey(DoM='20', Hour=21, Text=u'UTADontShoot'): 4,
#  HashtagKey(DoM='20', Hour=8, Text=u'HTAFC'): 1,
#  HashtagKey(DoM='17', Hour=20, Text=u'Gezi'): 3,
#  HashtagKey(DoM='20', Hour=17, Text=u'Physically'): 1,
#  HashtagKey(DoM='19', Hour=7, Text=u'TheRevolutionWillBeLivestreamed'): 1,
#  HashtagKey(DoM='19', Hour=17, Text=u'weird'): 1,
#  HashtagKey(DoM='19', Hour=11, Text=u'teamfollowback'): 1,
#  HashtagKey(DoM='19', Hour=14, Text=u'howdidthisstartagain'): 1,
#  HashtagKey(DoM='14', Hour=14, Text=u'civilrightsthrowback'): 1,
#  HashtagKey(DoM='20', Hour=6, Text=u'HowardUniversity'): 1,
#  HashtagKey(DoM='15', Hour=9, Text=u'janellemonae'): 2,
#  HashtagKey(DoM='19', Hour=20, Text=u'BREAKINGNEWS'): 2,
#  HashtagKey(DoM='20', Hour=11, Text=u'tinypass'): 1,
#  HashtagKey(DoM='20', Hour=17, Text=u'WhatchaDewinWednesday'): 1,
#  HashtagKey(DoM='21', Hour=0, Text=u'Benzino'): 1,
#  HashtagKey(DoM='18', Hour=2, Text=u'TRUTH'): 3,
#  HashtagKey(DoM='15', Hour=0, Text=u'NotTonight'): 1,
#  HashtagKey(DoM='20', Hour=13, Text=u'LATEST'): 16,
#  HashtagKey(DoM='20', Hour=15, Text=u'fuckferguson'): 1,
#  HashtagKey(DoM='20', Hour=21, Text=u'ThinkAboutIt'): 1,
#  HashtagKey(DoM='20', Hour=19, Text=u'TalkRadiance'): 1,
#  HashtagKey(DoM='20', Hour=19, Text=u'fergusonmo'): 1,
#  HashtagKey(DoM='21', Hour=1, Text=u'WorkTogether'): 1,
#  HashtagKey(DoM='20', Hour=21, Text=u'msm'): 1,
#  HashtagKey(DoM='18', Hour=1, Text=u'RacisminAmerica'): 3,
#  HashtagKey(DoM='19', Hour=22, Text=u'RickPerryIndicted'): 3,
#  HashtagKey(DoM='20', Hour=18, Text=u'CivilDisobedience'): 5,
#  HashtagKey(DoM='19', Hour=15, Text=u'wheretheangerstemsfrom'): 1,
#  HashtagKey(DoM='20', Hour=16, Text=u'soundsdumblikeFerguson'): 1,
#  HashtagKey(DoM='19', Hour=10, Text=u'LupenreineDemokratie'): 1,
#  HashtagKey(DoM='20', Hour=0, Text=u'PRNewser'): 1,
#  HashtagKey(DoM='15', Hour=3, Text=u'getmoneyout'): 3,
#  HashtagKey(DoM='19', Hour=20, Text=u'westbank'): 1,
#  HashtagKey(DoM='15', Hour=9, Text=u'tlot'): 5,
#  HashtagKey(DoM='20', Hour=18, Text=u'Provocateur'): 1,
#  HashtagKey(DoM='18', Hour=2, Text=u'maturin'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'RayNixon'): 1,
#  HashtagKey(DoM='19', Hour=21, Text=u'4Raba'): 1,
#  HashtagKey(DoM='19', Hour=13, Text=u'Pentagon'): 8,
#  HashtagKey(DoM='15', Hour=2, Text=u'Fixed'): 1,
#  HashtagKey(DoM='17', Hour=19, Text=u'operationmarthasvineyard'): 15,
#  HashtagKey(DoM='14', Hour=17, Text=u'gunfail'): 3,
#  HashtagKey(DoM='15', Hour=1, Text=u'Rage'): 1,
#  HashtagKey(DoM='19', Hour=21, Text=u'TWIBNation'): 1,
#  HashtagKey(DoM='14', Hour=15, Text=u'Jumia'): 2,
#  HashtagKey(DoM='19', Hour=20, Text=u'NewYork'): 5,
#  HashtagKey(DoM='21', Hour=1, Text=u'classy'): 1,
#  HashtagKey(DoM='21', Hour=0, Text=u'NorthSTL'): 1,
#  HashtagKey(DoM='19', Hour=22, Text=u'Nachrichten'): 1,
#  HashtagKey(DoM='19', Hour=18, Text=u'blog'): 3,
#  HashtagKey(DoM='20', Hour=5, Text=u'GOP'): 5,
#  HashtagKey(DoM='21', Hour=1, Text=u'Betterthanteargas'): 1,
#  HashtagKey(DoM='20', Hour=4, Text=u'nhv'): 19,
#  HashtagKey(DoM='20', Hour=21, Text=u'fuckthepolice'): 1,
#  HashtagKey(DoM='19', Hour=23, Text=u'CommieInsiders'): 1,
#  HashtagKey(DoM='19', Hour=16, Text=u'mediacensorship'): 3,
#  ...}

# %%
def plotHashtags(DoM, Hour,nHashTags=20):
#     print(DoM,Hour)
    timeHashtags = {key: value for key,value in aggDict.items() if (key.DoM == str(DoM) and key.Hour == Hour)}
#     print timeHashtags
    sortedByCount = sorted(timeHashtags.items(), key=lambda x: (x[1],x[0].Text), reverse=True)
#     print(sortedByCount)
    dictList = [list(t) for t in zip(*sortedByCount)]
    hashtags = [x.Text for x in dictList[0]]
    counts = dictList[1]
#     print counts[0:nHashTags]
    plt.title('Hashtag Distribution (Dec {0} at {1})'.format(DoM, Hour))
    plt.ylabel('Number of Tweets')
    plt.bar(range(len(counts[0:nHashTags])), counts[0:nHashTags], width = 1)
    plt.xticks([x+0.5 for x in range(len(counts[0:nHashTags]))], hashtags[0:nHashTags], rotation='vertical')

# %%
DoM = widgets.IntSlider(min=10, max=27, value=15)
Hour = widgets.IntSlider(min=0, max=23, value=10)
nHashTags = widgets.IntSlider(min=0, max=40, value=50)
widgets.interact(plotHashtags, DoM=DoM, Hour=Hour, nHashTags=nHashTags)
# Out:
# <function __main__.plotHashtags>
